# %% [markdown]
# Customizing Workflows
# ===================
#
# This notebook shows how to write workflows for BQSKit, using the Hubbard Model$^1$ as an exemplar. The Hubbard Model is only briefly introduced; full details on the Hubbard Model, the Variational Quantum Eigensolver, the effects of noise, and more, can be found as part of the scikit-quant tutorials.$^2$
#
# Prerequisites: OpenFermion, Qiskit, BQSKit, and SciPy (which will pull in NumPy), as well as optionally scikit-quant, e.g. install with pip:
#
# `$ python -m pip install openfermion qiskit bqskit scipy`

# %% [markdown]
# Contents
# -----------
#
# This tutorial is setup to be run serially for the first several sections, as lessons learned (and code) are used in subsequent sections. However, afterwards it is possible to skip and jump ahead if a specific focus is of more interest.
#
# * Work through in series:
#    * [Introduction to the Hubbard Model](#Introduction)
#    * [Effects of circuit structure on synthesis](#Energy-Objective)
#    * [Running BQSKit synthesis in VQE](#Variational-Quantum-Eigensolver)
# * Work through in series, or pick and choose:
#    * [Customizing BQSKit workflows](#Customized-Compilation)
#    * [Seeded synthesis](#Seeded-Synthesis)

# %% [markdown]
# Introduction
# --------------
#
# We will solve the Hubbard Model using the Variational Quantum Eigensolver (VQE) algorithm. The Hubbard Model (HM) has a range of uses, most notably in solid-state physics to explain phase transitions and other correlated behaviors. There are several variations of the HM, but in essence, the model describes interacting particles on a lattice. Despite its apparent simplicity, it is hard to solve on a classical computer because the known algorithms scale exponentially unless further approximations are made. In this tutorial, we will use the VQE algorithm to estimate the energy ground states of different configurations of an HM.

# %% [markdown]
# Basic Fermi-Hubbard Model
# ---------------------------------
#
# We will restrict ourselves to a Hubbard Model with fermions (such as electrons), i.e. the Fermi-Hubbard Model. A visualization of an example with a 2x2 grid with spinful electrons is shown below. Electrons being fermions means that two electrons can not occupy the same quantum state. Because the electrons have spin, there can thus be at most two electrons per site (one spin-up, one spin-down). The model is characterized by an interaction term 'U', which only contributes if a spin-up and a spin-down electron occupy the same site; and by a "hopping" term 't', representing the kinetic energy in the system. In this basic model, only hops to neighboring sites are considered.
#
# <table style="padding: 0px"><tr></tr><tr>
# <td style="width: 65%; padding: 0px">
# <div align="left" style="text-align: left; font-size: 120%">
# The energy in the model is described by the following Hamiltonian using fermion algebra:
# <br>
# <p>\begin{equation*}
# H = -t \sum_{ij,\sigma=\uparrow\downarrow} {a_{i\sigma}^\dagger a_{j\sigma}} + U \sum_i {a_{i\uparrow}^\dagger a_{i\uparrow} a_{i\downarrow}^\dagger a_{i\downarrow}}
# \end{equation*}</p>
# where:
# <ul>
#     <li>$a_{i\sigma}^\dagger$ = creation operator for site 'i' and spin $\sigma$</li>
#     <li>$a_{i\sigma}$ = annihilation operator for site 'i' and spin $\sigma$</li>
#     <li>U = interaction term</li>
#     <li>t = hopping term</li>
# </ul>
# <p>The first sum quantifies moving electrons from each site 'j' to each neighboring site 'i' (first term, that is: $a_i^\dagger$ "creates" an electron at site 'i' while $a_j$ simultaneously "annihilates" it from site 'j'), and vice versa (second term), considering both up and down spins ($\sigma$) independently; the second sum quantifies the interaction contribution for having two electrons, one up and one down, at the same site 'i'.
# </p></div></td>
#     <td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
# <td style="width: 35%">
#     <img src='./images/basic_fermi_hubbard_model.png'>
# </td>
# </tr></table>
#
# <p>
# Although the pictorial shows the electrons as concrete particles, the model treats them as waves that extend over all sites. A solution to the model provides the probabilities with which any of the electrons can be measured, as a particle, at each one of the sites.

# %% [markdown]
# Mapping fermions to qubits
# ---------------------------------
#
# Fermion algebra is only a subset of what a quantum computer can express, since fermions are interchangeable and many states are thus completely equivalent, whereas qubits are identifiable (each one has a well defined location on a chip or ion trap, for example). Thus, it is useful to perform a mapping from fermion to qubit algebra that preserves the fermionic relations, to ensure that the mapped operators only produce states inside that fermionic subset; meaning that the computation should not, noise aside, produce non-physical states. Doing so reduces the scope for errors.$^3$
#
# There are several possible mappings from fermion to qubit operators that preserve the fermion algebra. Here, we'll consider the Jordan-Wigner$^4$ and Bravyi-Kitaev$^5$ transforms, because these are commonly used and easy to understand and their differences$^6$ show an important point about how the optimizability of circuits.
#
# To get started, first load some relevant modules and helper functions.

# %%
# %load_ext autoreload

# %%
# useful tools
import logging
import numpy as np
import qiskit as qk
import scipy
from timeit import default_timer as timer

# BQSKit tooling
import bqskit
from bqskit.ext import qiskit_to_bqskit

# VQE objective function for Hamiltonians
from hubbard import EnergyObjective, hamiltonian_qiskit, hubbard

# %%
def display_circuit(circuit, basis=['u', 'cx']):
    """perform basic, unoptimized decomposition for circuit display"""

    uc =  qk.transpile(circuit, basis_gates=basis)
    
    for gate, count in uc.count_ops().items():
        print("gate %s count: %d" % (gate, count))

    return uc.draw()

# %% [markdown]
# The Fermi-Hubbard model is defined by the dimensions of the 2D grid, plus the hopping and interaction terms. In addition, OpenFermion allows some variations on the team by making the electrons spinless and making the grid periodic. Below is a very small model, just 2 sites (2x1), which will result in 2 classical optimization parameters. You can try a larger model, but this small example is chosen for a tutorial session where it can be easily run on a laptop on battery power.

# %%
# Setup for a 2x1 grid with a single electron.
hm_lattice = {
    'x_dimension' : 2,
    'y_dimension' : 1,      # 2D x_dim * y_dim grid
    'tunneling'   : 1.0,    # hpping term `t`
    'coulomb'     : 2.0,    # interaction term `U`
    'spinless'    : False,  # double negative, so do have spins
    'periodic'    : False,  # do not allow wrap-around hopping
}

hm_filling = {
    'n_electrons_up'   : 1,
    'n_electrons_down' : 0,
}

# %% [markdown]
# Energy Objective
# --------------------
#
# The Variational Quantum Eigensolver is an iterative algorithm where a classical optimizer minimizes an energy objective (the expectation value of the Hamiltonian) as calculated on the quantum computer. Typically, an Hamiltonian has many components, which can be evaluated in parallel, on separate quantum chips/computers. The final result is obtained by summing the parts classically using their proper weights.
# <table style="padding: 0px"><tr></tr><tr>
# <td style="width: 60%; padding: 0px">
# <div align="left" style="text-align: left; font-size: 120%">
# The trial quantum states proposed by the classical optimizer are constructed using an <i>Ansatz</i> that is parametrized using classical values only.
# Here, we wil use <i>Unitary Coupled Cluster</i> Ansatz for single and double excitations (UCCSD). Briefly, this Ansatz explores the search space by moving single electrons and by swapping pairs.
# This Ansatz is easier on the classical optimizer than many alternatives, but produces rather deep circuits, which is why the use of a tool like BQSKit becomes a necessity.
# </div></td>
# <td><img src='./images/vqe_structure.png'></td>
# </tr></table>
# To complete a circuit, we need to fill it with electrons and then instantiate the circuit for a set of optimization paremeters. Note that the meaning of these parameters depends on the chosen mapping.

# %%
# Hubbard Model Hamiltonian using Jordan-Wigner mapping
hm_jw = hamiltonian_qiskit(fermion_transform='jordan-wigner', **hm_lattice)

# create an energy objective, which can be minimized classically, from the mapped hamiltonian
jw_objective = EnergyObjective(hm_jw, **hm_filling)

# instantiate a circuit from a set of classical parameters
jw_circuit_instance = jw_objective.generate_circuit([0.1]*jw_objective.npar())

# visualize the circuit, using basic gates, and collect some statistics
c_jw = qk.transpile(jw_circuit_instance, basis_gates=["u3", "cx"])

for gate, count in c_jw.count_ops().items():
    print("gate %s count: %d" % (gate, count))
    
c_jw.draw()
# Out:
# gate cx count: 124
# gate u3 count: 110
# global phase: 0
#      ┌───────────────┐          ┌───┐┌────────────────┐┌───┐┌────────────────┐»
# q_0: ┤ U3(π/2,-π,-π) ├──────────┤ X ├┤ U3(0,0,-0.025) ├┤ X ├┤ U3(0,π/2,-π/2) ├»
#      └┬─────────────┬┘     ┌───┐└─┬─┘└────────────────┘└─┬─┘└─────┬───┬──────┘»
# q_1: ─┤ U3(π/2,0,π) ├──────┤ X ├──■──────────────────────■────────┤ X ├───────»
#       ├─────────────┤ ┌───┐└─┬─┘                                  └─┬─┘       »
# q_2: ─┤ U3(π/2,0,π) ├─┤ X ├──■──────────────────────────────────────■─────────»
#      ┌┴─────────────┴┐└─┬─┘                                                   »
# q_3: ┤ U3(π/2,0,π/2) ├──■─────────────────────────────────────────────────────»
#      └───────────────┘                                                        »
# «                                                     ┌───┐┌────────────────┐»
# «q_0: ────────────────────────────────────────────────┤ X ├┤ U3(0,0,-0.025) ├»
# «     ┌────────────────┐                         ┌───┐└─┬─┘└────────────────┘»
# «q_1: ┤ U3(0,π/2,-π/2) ├─────────────────────────┤ X ├──■────────────────────»
# «     └─────┬───┬──────┘┌──────────────────┐┌───┐└─┬─┘                       »
# «q_2: ──────┤ X ├───────┤ U3(π/2,π/2,-π/2) ├┤ X ├──■─────────────────────────»
# «           └─┬─┘       ├──────────────────┤└─┬─┘                            »
# «q_3: ────────■─────────┤ U3(π/2,-π/2,π/2) ├──■──────────────────────────────»
# «                       └──────────────────┘                                 »
# «     ┌───┐┌────────────────┐                                                  »
# «q_0: ┤ X ├┤ U3(0,π/2,-π/2) ├──────────────────────────────────────────────────»
# «     └─┬─┘└─────┬───┬──────┘┌──────────────────┐                         ┌───┐»
# «q_1: ──■────────┤ X ├───────┤ U3(π/2,π/2,-π/2) ├─────────────────────────┤ X ├»
# «                └─┬─┘       └──────┬───┬───────┘┌──────────────────┐┌───┐└─┬─┘»
# «q_2: ─────────────■────────────────┤ X ├────────┤ U3(π/2,-π/2,π/2) ├┤ X ├──■──»
# «                                   └─┬─┘        └┬────────────────┬┘└─┬─┘     »
# «q_3: ────────────────────────────────■───────────┤ U3(0,π/2,-π/2) ├───■───────»
# «                                                 └────────────────┘           »
# «     ┌───┐┌───────────────┐┌───┐┌────────────────┐                  »
# «q_0: ┤ X ├┤ U3(0,0,0.025) ├┤ X ├┤ U3(0,π/2,-π/2) ├──────────────────»
# «     └─┬─┘└───────────────┘└─┬─┘└─────┬───┬──────┘┌────────────────┐»
# «q_1: ──■─────────────────────■────────┤ X ├───────┤ U3(0,π/2,-π/2) ├»
# «                                      └─┬─┘       └─────┬───┬──────┘»
# «q_2: ───────────────────────────────────■───────────────┤ X ├───────»
# «                                                        └─┬─┘       »
# «q_3: ─────────────────────────────────────────────────────■─────────»
# «                                                                    »
# «                                   ┌───┐┌────────────────┐┌───┐»
# «q_0: ──────────────────────────────┤ X ├┤ U3(0,0,-0.025) ├┤ X ├»
# «                              ┌───┐└─┬─┘└────────────────┘└─┬─┘»
# «q_1: ─────────────────────────┤ X ├──■──────────────────────■──»
# «     ┌──────────────────┐┌───┐└─┬─┘                            »
# «q_2: ┤ U3(π/2,π/2,-π/2) ├┤ X ├──■──────────────────────────────»
# «     ├──────────────────┤└─┬─┘                                 »
# «q_3: ┤ U3(π/2,π/2,-π/2) ├──■───────────────────────────────────»
# «     └──────────────────┘                                      »
# «     ┌────────────────┐                                           ┌───┐»
# «q_0: ┤ U3(0,π/2,-π/2) ├───────────────────────────────────────────┤ X ├»
# «     └─────┬───┬──────┘┌────────────────┐                    ┌───┐└─┬─┘»
# «q_1: ──────┤ X ├───────┤ U3(π/2,π/2,-π) ├────────────────────┤ X ├──■──»
# «           └─┬─┘       └─────┬───┬──────┘ ┌────────────────┐ └─┬─┘     »
# «q_2: ────────■───────────────┤ X ├────────┤ U3(0,π/2,-π/2) ├───■───────»
# «                             └─┬─┘       ┌┴────────────────┴┐          »
# «q_3: ──────────────────────────■─────────┤ U3(π/2,-π/2,π/2) ├──────────»
# «                                         └──────────────────┘          »
# «     ┌───────────────┐┌───┐┌──────────────────┐                              »
# «q_0: ┤ U3(0,0,-0.05) ├┤ X ├┤ U3(π/2,π/2,-π/2) ├──────────────────────────────»
# «     └───────────────┘└─┬─┘└──────┬───┬───────┘  ┌─────────────┐        ┌───┐»
# «q_1: ───────────────────■─────────┤ X ├──────────┤ U3(π/2,0,π) ├────────┤ X ├»
# «                                  └─┬─┘        ┌─┴─────────────┴──┐┌───┐└─┬─┘»
# «q_2: ───────────────────────────────■──────────┤ U3(π/2,-π/2,π/2) ├┤ X ├──■──»
# «                                               └──────────────────┘└─┬─┘     »
# «q_3: ────────────────────────────────────────────────────────────────■───────»
# «                                                                             »
# «     ┌───┐┌───────────────┐┌───┐┌────────────────┐                  »
# «q_0: ┤ X ├┤ U3(0,0,0.025) ├┤ X ├┤ U3(0,π/2,-π/2) ├──────────────────»
# «     └─┬─┘└───────────────┘└─┬─┘└─────┬───┬──────┘┌────────────────┐»
# «q_1: ──■─────────────────────■────────┤ X ├───────┤ U3(0,π/2,-π/2) ├»
# «                                      └─┬─┘       └─────┬───┬──────┘»
# «q_2: ───────────────────────────────────■───────────────┤ X ├───────»
# «                                                        └─┬─┘       »
# «q_3: ─────────────────────────────────────────────────────■─────────»
# «                                                                    »
# «                                   ┌───┐┌────────────────┐┌───┐»
# «q_0: ──────────────────────────────┤ X ├┤ U3(0,0,-0.025) ├┤ X ├»
# «                              ┌───┐└─┬─┘└────────────────┘└─┬─┘»
# «q_1: ─────────────────────────┤ X ├──■──────────────────────■──»
# «     ┌──────────────────┐┌───┐└─┬─┘                            »
# «q_2: ┤ U3(π/2,π/2,-π/2) ├┤ X ├──■──────────────────────────────»
# «     ├──────────────────┤└─┬─┘                                 »
# «q_3: ┤ U3(π/2,π/2,-π/2) ├──■───────────────────────────────────»
# «     └──────────────────┘                                      »
# «     ┌────────────────┐                                                  ┌───┐»
# «q_0: ┤ U3(0,π/2,-π/2) ├──────────────────────────────────────────────────┤ X ├»
# «     └─────┬───┬──────┘┌──────────────────┐                         ┌───┐└─┬─┘»
# «q_1: ──────┤ X ├───────┤ U3(π/2,π/2,-π/2) ├─────────────────────────┤ X ├──■──»
# «           └─┬─┘       └──────┬───┬───────┘┌──────────────────┐┌───┐└─┬─┘     »
# «q_2: ────────■────────────────┤ X ├────────┤ U3(π/2,-π/2,π/2) ├┤ X ├──■───────»
# «                              └─┬─┘        └┬────────────────┬┘└─┬─┘          »
# «q_3: ───────────────────────────■───────────┤ U3(0,π/2,-π/2) ├───■────────────»
# «                                            └────────────────┘                »
# «     ┌───────────────┐┌───┐┌────────────────┐                  »
# «q_0: ┤ U3(0,0,0.025) ├┤ X ├┤ U3(0,π/2,-π/2) ├──────────────────»
# «     └───────────────┘└─┬─┘└─────┬───┬──────┘┌────────────────┐»
# «q_1: ───────────────────■────────┤ X ├───────┤ U3(0,π/2,-π/2) ├»
# «                                 └─┬─┘       └─────┬───┬──────┘»
# «q_2: ──────────────────────────────■───────────────┤ X ├───────»
# «                                                   └─┬─┘       »
# «q_3: ────────────────────────────────────────────────■─────────»
# «                                                               »
# «                                   ┌───┐┌───────────────┐┌───┐»
# «q_0: ──────────────────────────────┤ X ├┤ U3(0,0,0.025) ├┤ X ├»
# «                              ┌───┐└─┬─┘└───────────────┘└─┬─┘»
# «q_1: ─────────────────────────┤ X ├──■─────────────────────■──»
# «     ┌──────────────────┐┌───┐└─┬─┘                           »
# «q_2: ┤ U3(π/2,π/2,-π/2) ├┤ X ├──■─────────────────────────────»
# «     ├──────────────────┤└─┬─┘                                »
# «q_3: ┤ U3(π/2,-π/2,π/2) ├──■──────────────────────────────────»
# «     └──────────────────┘                                     »
# «     ┌────────────────┐                                           ┌───┐»
# «q_0: ┤ U3(0,π/2,-π/2) ├───────────────────────────────────────────┤ X ├»
# «     └─────┬───┬──────┘┌────────────────┐                    ┌───┐└─┬─┘»
# «q_1: ──────┤ X ├───────┤ U3(π/2,π/2,-π) ├────────────────────┤ X ├──■──»
# «           └─┬─┘       └─────┬───┬──────┘┌──────────────────┐└─┬─┘     »
# «q_2: ────────■───────────────┤ X ├───────┤ U3(π/2,-π/2,π/2) ├──■───────»
# «                             └─┬─┘       ├──────────────────┤          »
# «q_3: ──────────────────────────■─────────┤ U3(π/2,π/2,-π/2) ├──────────»
# «                                         └──────────────────┘          »
# «     ┌──────────────┐┌───┐┌────────────────┐                         »
# «q_0: ┤ U3(0,0,0.05) ├┤ X ├┤ U3(0,π/2,-π/2) ├─────────────────────────»
# «     └──────────────┘└─┬─┘└─────┬───┬──────┘┌─────────────┐     ┌───┐»
# «q_1: ──────────────────■────────┤ X ├───────┤ U3(π/2,0,π) ├─────┤ X ├»
# «                                └─┬─┘       ├─────────────┤┌───┐└─┬─┘»
# «q_2: ─────────────────────────────■─────────┤ U3(π/2,0,π) ├┤ X ├──■──»
# «                                            └─────────────┘└─┬─┘     »
# «q_3: ────────────────────────────────────────────────────────■───────»
# «                                                                     »
# «                                                                             »
# «q_0: ────────────────────────────────────────────────────────────────────────»
# «     ┌───────────────┐┌───┐┌──────────────────┐                         ┌───┐»
# «q_1: ┤ U3(0,0,-0.05) ├┤ X ├┤ U3(π/2,π/2,-π/2) ├─────────────────────────┤ X ├»
# «     └───────────────┘└─┬─┘└──────┬───┬───────┘                    ┌───┐└─┬─┘»
# «q_2: ───────────────────■─────────┤ X ├────────────────────────────┤ X ├──■──»
# «                                  └─┬─┘        ┌──────────────────┐└─┬─┘     »
# «q_3: ───────────────────────────────■──────────┤ U3(π/2,-π/2,π/2) ├──■───────»
# «                                               └──────────────────┘          »
# «                                                                           »
# «q_0: ──────────────────────────────────────────────────────────────────────»
# «     ┌─────────────┐┌───┐┌──────────────────┐                         ┌───┐»
# «q_1: ┤ U3(0,0,0.1) ├┤ X ├┤ U3(π/2,-π/2,π/2) ├─────────────────────────┤ X ├»
# «     └─────────────┘└─┬─┘└──────┬───┬───────┘                    ┌───┐└─┬─┘»
# «q_2: ─────────────────■─────────┤ X ├────────────────────────────┤ X ├──■──»
# «                                └─┬─┘        ┌──────────────────┐└─┬─┘     »
# «q_3: ─────────────────────────────■──────────┤ U3(π/2,π/2,-π/2) ├──■───────»
# «                                             └──────────────────┘          »
# «                                                                   ┌───┐»
# «q_0: ──────────────────────────────────────────────────────────────┤ X ├»
# «     ┌───────────────┐┌───┐┌─────────────┐                    ┌───┐└─┬─┘»
# «q_1: ┤ U3(0,0,-0.05) ├┤ X ├┤ U3(π/2,0,π) ├────────────────────┤ X ├──■──»
# «     └───────────────┘└─┬─┘└────┬───┬────┘  ┌─────────────┐   └─┬─┘     »
# «q_2: ───────────────────■───────┤ X ├───────┤ U3(π/2,0,π) ├─────■───────»
# «                                └─┬─┘     ┌─┴─────────────┴──┐          »
# «q_3: ─────────────────────────────■───────┤ U3(π/2,-π/2,π/2) ├──────────»
# «                                          └──────────────────┘          »
# «     ┌──────────────┐┌───┐┌────────────────┐                              »
# «q_0: ┤ U3(0,0,0.05) ├┤ X ├┤ U3(0,π/2,-π/2) ├──────────────────────────────»
# «     └──────────────┘└─┬─┘└─────┬───┬──────┘ ┌───────────────┐       ┌───┐»
# «q_1: ──────────────────■────────┤ X ├────────┤ U3(π/2,0,π/2) ├───────┤ X ├»
# «                                └─┬─┘       ┌┴───────────────┴─┐┌───┐└─┬─┘»
# «q_2: ─────────────────────────────■─────────┤ U3(π/2,π/2,-π/2) ├┤ X ├──■──»
# «                                            └──────────────────┘└─┬─┘     »
# «q_3: ─────────────────────────────────────────────────────────────■───────»
# «                                                                          »
# «     ┌───┐┌───────────────┐┌───┐┌────────────────┐                  »
# «q_0: ┤ X ├┤ U3(0,0,0.025) ├┤ X ├┤ U3(0,π/2,-π/2) ├──────────────────»
# «     └─┬─┘└───────────────┘└─┬─┘└─────┬───┬──────┘┌────────────────┐»
# «q_1: ──■─────────────────────■────────┤ X ├───────┤ U3(0,π/2,-π/2) ├»
# «                                      └─┬─┘       └─────┬───┬──────┘»
# «q_2: ───────────────────────────────────■───────────────┤ X ├───────»
# «                                                        └─┬─┘       »
# «q_3: ─────────────────────────────────────────────────────■─────────»
# «                                                                    »
# «                                   ┌───┐┌───────────────┐┌───┐»
# «q_0: ──────────────────────────────┤ X ├┤ U3(0,0,0.025) ├┤ X ├»
# «                              ┌───┐└─┬─┘└───────────────┘└─┬─┘»
# «q_1: ─────────────────────────┤ X ├──■─────────────────────■──»
# «     ┌──────────────────┐┌───┐└─┬─┘                           »
# «q_2: ┤ U3(π/2,-π/2,π/2) ├┤ X ├──■─────────────────────────────»
# «     ├──────────────────┤└─┬─┘                                »
# «q_3: ┤ U3(π/2,π/2,-π/2) ├──■──────────────────────────────────»
# «     └──────────────────┘                                     »
# «     ┌────────────────┐                                                  ┌───┐»
# «q_0: ┤ U3(0,π/2,-π/2) ├──────────────────────────────────────────────────┤ X ├»
# «     └─────┬───┬──────┘┌──────────────────┐                         ┌───┐└─┬─┘»
# «q_1: ──────┤ X ├───────┤ U3(π/2,-π/2,π/2) ├─────────────────────────┤ X ├──■──»
# «           └─┬─┘       └──────┬───┬───────┘┌──────────────────┐┌───┐└─┬─┘     »
# «q_2: ────────■────────────────┤ X ├────────┤ U3(π/2,π/2,-π/2) ├┤ X ├──■───────»
# «                              └─┬─┘        └┬────────────────┬┘└─┬─┘          »
# «q_3: ───────────────────────────■───────────┤ U3(0,π/2,-π/2) ├───■────────────»
# «                                            └────────────────┘                »
# «     ┌────────────────┐┌───┐┌────────────────┐                  »
# «q_0: ┤ U3(0,0,-0.025) ├┤ X ├┤ U3(0,π/2,-π/2) ├──────────────────»
# «     └────────────────┘└─┬─┘└─────┬───┬──────┘┌────────────────┐»
# «q_1: ────────────────────■────────┤ X ├───────┤ U3(0,π/2,-π/2) ├»
# «                                  └─┬─┘       └─────┬───┬──────┘»
# «q_2: ───────────────────────────────■───────────────┤ X ├───────»
# «                                                    └─┬─┘       »
# «q_3: ─────────────────────────────────────────────────■─────────»
# «                                                                »
# «                                   ┌───┐┌───────────────┐┌───┐»
# «q_0: ──────────────────────────────┤ X ├┤ U3(0,0,0.025) ├┤ X ├»
# «                              ┌───┐└─┬─┘└───────────────┘└─┬─┘»
# «q_1: ─────────────────────────┤ X ├──■─────────────────────■──»
# «     ┌──────────────────┐┌───┐└─┬─┘                           »
# «q_2: ┤ U3(π/2,-π/2,π/2) ├┤ X ├──■─────────────────────────────»
# «     ├──────────────────┤└─┬─┘                                »
# «q_3: ┤ U3(π/2,-π/2,π/2) ├──■──────────────────────────────────»
# «     └──────────────────┘                                     »
# «     ┌──────────────────┐                                        ┌───┐»
# «q_0: ┤ U3(π/2,-π/2,π/2) ├────────────────────────────────────────┤ X ├»
# «     └──────┬───┬───────┘┌─────────────┐                    ┌───┐└─┬─┘»
# «q_1: ───────┤ X ├────────┤ U3(π/2,0,π) ├────────────────────┤ X ├──■──»
# «            └─┬─┘        └────┬───┬────┘┌──────────────────┐└─┬─┘     »
# «q_2: ─────────■───────────────┤ X ├─────┤ U3(π/2,π/2,-π/2) ├──■───────»
# «                              └─┬─┘     ├──────────────────┤          »
# «q_3: ───────────────────────────■───────┤ U3(π/2,π/2,-π/2) ├──────────»
# «                                        └──────────────────┘          »
# «     ┌───────────────┐┌───┐┌────────────────┐                            ┌───┐»
# «q_0: ┤ U3(0,0,-0.05) ├┤ X ├┤ U3(0,π/2,-π/2) ├────────────────────────────┤ X ├»
# «     └───────────────┘└─┬─┘└─────┬───┬──────┘┌───────────────┐      ┌───┐└─┬─┘»
# «q_1: ───────────────────■────────┤ X ├───────┤ U3(π/2,0,π/2) ├──────┤ X ├──■──»
# «                                 └─┬─┘       ├───────────────┴┐┌───┐└─┬─┘     »
# «q_2: ──────────────────────────────■─────────┤ U3(0,π/2,-π/2) ├┤ X ├──■───────»
# «                                             └────────────────┘└─┬─┘          »
# «q_3: ────────────────────────────────────────────────────────────■────────────»
# «                                                                              »
# «     ┌────────────────┐┌───┐┌────────────────┐                  »
# «q_0: ┤ U3(0,0,-0.025) ├┤ X ├┤ U3(0,π/2,-π/2) ├──────────────────»
# «     └────────────────┘└─┬─┘└─────┬───┬──────┘┌────────────────┐»
# «q_1: ────────────────────■────────┤ X ├───────┤ U3(0,π/2,-π/2) ├»
# «                                  └─┬─┘       └─────┬───┬──────┘»
# «q_2: ───────────────────────────────■───────────────┤ X ├───────»
# «                                                    └─┬─┘       »
# «q_3: ─────────────────────────────────────────────────■─────────»
# «                                                                »
# «                                   ┌───┐┌───────────────┐┌───┐»
# «q_0: ──────────────────────────────┤ X ├┤ U3(0,0,0.025) ├┤ X ├»
# «                              ┌───┐└─┬─┘└───────────────┘└─┬─┘»
# «q_1: ─────────────────────────┤ X ├──■─────────────────────■──»
# «     ┌──────────────────┐┌───┐└─┬─┘                           »
# «q_2: ┤ U3(π/2,-π/2,π/2) ├┤ X ├──■─────────────────────────────»
# «     ├──────────────────┤└─┬─┘                                »
# «q_3: ┤ U3(π/2,-π/2,π/2) ├──■──────────────────────────────────»
# «     └──────────────────┘                                     »
# «     ┌────────────────┐                                                  ┌───┐»
# «q_0: ┤ U3(0,π/2,-π/2) ├──────────────────────────────────────────────────┤ X ├»
# «     └─────┬───┬──────┘┌──────────────────┐                         ┌───┐└─┬─┘»
# «q_1: ──────┤ X ├───────┤ U3(π/2,-π/2,π/2) ├─────────────────────────┤ X ├──■──»
# «           └─┬─┘       └──────┬───┬───────┘┌──────────────────┐┌───┐└─┬─┘     »
# «q_2: ────────■────────────────┤ X ├────────┤ U3(π/2,π/2,-π/2) ├┤ X ├──■───────»
# «                              └─┬─┘        └┬────────────────┬┘└─┬─┘          »
# «q_3: ───────────────────────────■───────────┤ U3(0,π/2,-π/2) ├───■────────────»
# «                                            └────────────────┘                »
# «     ┌────────────────┐┌───┐┌────────────────┐                  »
# «q_0: ┤ U3(0,0,-0.025) ├┤ X ├┤ U3(0,π/2,-π/2) ├──────────────────»
# «     └────────────────┘└─┬─┘└─────┬───┬──────┘┌────────────────┐»
# «q_1: ────────────────────■────────┤ X ├───────┤ U3(0,π/2,-π/2) ├»
# «                                  └─┬─┘       └─────┬───┬──────┘»
# «q_2: ───────────────────────────────■───────────────┤ X ├───────»
# «                                                    └─┬─┘       »
# «q_3: ─────────────────────────────────────────────────■─────────»
# «                                                                »
# «                                   ┌───┐┌────────────────┐┌───┐┌─────────────┐»
# «q_0: ──────────────────────────────┤ X ├┤ U3(0,0,-0.025) ├┤ X ├┤ U3(π/2,0,π) ├»
# «                              ┌───┐└─┬─┘└────────────────┘└─┬─┘└────┬───┬────┘»
# «q_1: ─────────────────────────┤ X ├──■──────────────────────■───────┤ X ├─────»
# «     ┌──────────────────┐┌───┐└─┬─┘                                 └─┬─┘     »
# «q_2: ┤ U3(π/2,-π/2,π/2) ├┤ X ├──■─────────────────────────────────────■───────»
# «     ├──────────────────┤└─┬─┘                                                »
# «q_3: ┤ U3(π/2,π/2,-π/2) ├──■──────────────────────────────────────────────────»
# «     └──────────────────┘                                                     »
# «
# «q_0: ─────────────────────────────────
# «     ┌─────────────┐
# «q_1: ┤ U3(π/2,0,π) ├──────────────────
# «     └────┬───┬────┘ ┌─────────────┐
# «q_2: ─────┤ X ├──────┤ U3(π/2,0,π) ├──
# «          └─┬─┘     ┌┴─────────────┴─┐
# «q_3: ───────■───────┤ U3(π/2,π/2,-π) ├
# «                    └────────────────┘

# %% [markdown]
# **Exercise:** Instantiate an energy objective like before, but now for the Bravyi-Kitaev mapping. Draw and compare the generated circuits, find the main differences in structure, and try to guess how that might affect the synthesis, in particular based on what you have learned about partitioning.

# %%
# Hubbard Model Hamiltonian using Bravyi-Kitaev mapping
hm_bk = hamiltonian_qiskit(fermion_transform='bravyi-kitaev', **hm_lattice)

# create an energy objective, which can be minimized classically, from the mapped hamiltonian
bk_objective = EnergyObjective(hm_bk, **hm_filling)

# instantiate a circuit from a set of classical parameters
bk_circuit_instance = bk_objective.generate_circuit([0.1]*bk_objective.npar())

# visualize the circuit, using basic gates, and collect some statistics
c_bk = qk.transpile(bk_circuit_instance, basis_gates=["u3", "cx"])

for gate, count in c_bk.count_ops().items():
    print("gate %s count: %d" % (gate, count))
    
c_bk.draw()
# Out:
# gate cx count: 90
# gate u3 count: 80
# global phase: 4.6124
#       ┌───────────────┐      ┌───┐┌──────────────┐┌───┐┌────────────────┐»
# q_0: ─┤ U3(π/2,-π,-π) ├──────┤ X ├┤ U3(0,0,0.05) ├┤ X ├┤ U3(0,π/2,-π/2) ├»
#      ┌┴───────────────┴┐┌───┐└─┬─┘└──────────────┘└─┬─┘└─────┬───┬──────┘»
# q_1: ┤ U3(π/2,-π,-π/2) ├┤ X ├──■────────────────────■────────┤ X ├───────»
#      └─┬─────────────┬─┘└─┬─┘                                └─┬─┘       »
# q_2: ──┤ U3(π/2,0,π) ├────■────────────────────────────────────■─────────»
#        └┬───────────┬┘                                                   »
# q_3: ───┤ U3(π,0,π) ├────────────────────────────────────────────────────»
#         └───────────┘                                                    »
# «                              ┌───┐┌────────────────┐┌───┐┌────────────────┐»
# «q_0: ─────────────────────────┤ X ├┤ U3(0,0,-0.025) ├┤ X ├┤ U3(0,π/2,-π/2) ├»
# «      ┌────────────────┐ ┌───┐└─┬─┘└────────────────┘└─┬─┘└─────┬───┬──────┘»
# «q_1: ─┤ U3(π/2,π/2,-π) ├─┤ X ├──■──────────────────────■────────┤ X ├───────»
# «     ┌┴────────────────┴┐└─┬─┘                                  └─┬─┘       »
# «q_2: ┤ U3(π/2,π/2,-π/2) ├──■──────────────────────────────────────■─────────»
# «     └──────────────────┘                                                   »
# «q_3: ───────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «                                 ┌───┐┌────────────────┐┌───┐»
# «q_0: ────────────────────────────┤ X ├┤ U3(0,0,-0.025) ├┤ X ├»
# «                            ┌───┐└─┬─┘└────────────────┘└─┬─┘»
# «q_1: ───────────────────────┤ X ├──■──────────────────────■──»
# «     ┌────────────────┐┌───┐└─┬─┘                            »
# «q_2: ┤ U3(0,π/2,-π/2) ├┤ X ├──■──────────────────────────────»
# «     └────────────────┘└─┬─┘                                 »
# «q_3: ────────────────────■───────────────────────────────────»
# «                                                             »
# «     ┌────────────────┐                                   ┌───┐»
# «q_0: ┤ U3(0,π/2,-π/2) ├───────────────────────────────────┤ X ├»
# «     └─────┬───┬──────┘┌───────────────┐                  └─┬─┘»
# «q_1: ──────┤ X ├───────┤ U3(π/2,0,π/2) ├────────────────────┼──»
# «           └─┬─┘       └─────┬───┬─────┘┌────────────────┐  │  »
# «q_2: ────────■───────────────┤ X ├──────┤ U3(0,π/2,-π/2) ├──■──»
# «                             └─┬─┘      └────────────────┘     »
# «q_3: ──────────────────────────■───────────────────────────────»
# «                                                               »
# «     ┌────────────────┐┌───┐┌────────────────┐     ┌───┐┌────────────────┐»
# «q_0: ┤ U3(0,0,-0.025) ├┤ X ├┤ U3(0,π/2,-π/2) ├─────┤ X ├┤ U3(0,0,-0.025) ├»
# «     └────────────────┘└─┬─┘└────────────────┘     └─┬─┘└────────────────┘»
# «q_1: ────────────────────┼───────────────────────────┼────────────────────»
# «                         │  ┌────────────────┐┌───┐  │                    »
# «q_2: ────────────────────■──┤ U3(0,π/2,-π/2) ├┤ X ├──■────────────────────»
# «                            └────────────────┘└─┬─┘                       »
# «q_3: ───────────────────────────────────────────■─────────────────────────»
# «                                                                          »
# «     ┌───┐┌──────────────────┐                       ┌───┐┌──────────────┐»
# «q_0: ┤ X ├┤ U3(π/2,π/2,-π/2) ├───────────────────────┤ X ├┤ U3(0,0,0.05) ├»
# «     └─┬─┘└──────────────────┘                  ┌───┐└─┬─┘└──────────────┘»
# «q_1: ──┼────────────────────────────────────────┤ X ├──■──────────────────»
# «       │         ┌───┐        ┌────────────────┐└─┬─┘                     »
# «q_2: ──■─────────┤ X ├────────┤ U3(0,π/2,-π/2) ├──■───────────────────────»
# «                 └─┬─┘        └────────────────┘                          »
# «q_3: ──────────────■──────────────────────────────────────────────────────»
# «                                                                          »
# «     ┌───┐┌────────────────┐                         ┌───┐┌───────────────┐»
# «q_0: ┤ X ├┤ U3(0,π/2,-π/2) ├─────────────────────────┤ X ├┤ U3(0,0,0.025) ├»
# «     └─┬─┘└─────┬───┬──────┘ ┌────────────────┐ ┌───┐└─┬─┘└───────────────┘»
# «q_1: ──■────────┤ X ├────────┤ U3(π/2,π/2,-π) ├─┤ X ├──■───────────────────»
# «                └─┬─┘       ┌┴────────────────┴┐└─┬─┘                      »
# «q_2: ─────────────■─────────┤ U3(π/2,-π/2,π/2) ├──■────────────────────────»
# «                            └──────────────────┘                           »
# «q_3: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «     ┌───┐┌────────────────┐                            ┌───┐┌───────────────┐»
# «q_0: ┤ X ├┤ U3(0,π/2,-π/2) ├────────────────────────────┤ X ├┤ U3(0,0,0.025) ├»
# «     └─┬─┘└─────┬───┬──────┘                       ┌───┐└─┬─┘└───────────────┘»
# «q_1: ──■────────┤ X ├──────────────────────────────┤ X ├──■───────────────────»
# «                └─┬─┘       ┌────────────────┐┌───┐└─┬─┘                      »
# «q_2: ─────────────■─────────┤ U3(0,π/2,-π/2) ├┤ X ├──■────────────────────────»
# «                            └────────────────┘└─┬─┘                           »
# «q_3: ───────────────────────────────────────────■─────────────────────────────»
# «                                                                              »
# «     ┌───┐┌────────────────┐                                   ┌───┐»
# «q_0: ┤ X ├┤ U3(0,π/2,-π/2) ├───────────────────────────────────┤ X ├»
# «     └─┬─┘└─────┬───┬──────┘┌───────────────┐                  └─┬─┘»
# «q_1: ──■────────┤ X ├───────┤ U3(π/2,0,π/2) ├────────────────────┼──»
# «                └─┬─┘       └─────┬───┬─────┘┌────────────────┐  │  »
# «q_2: ─────────────■───────────────┤ X ├──────┤ U3(0,π/2,-π/2) ├──■──»
# «                                  └─┬─┘      └────────────────┘     »
# «q_3: ───────────────────────────────■───────────────────────────────»
# «                                                                    »
# «     ┌───────────────┐┌───┐┌────────────────┐     ┌───┐┌───────────────┐┌───┐»
# «q_0: ┤ U3(0,0,0.025) ├┤ X ├┤ U3(0,π/2,-π/2) ├─────┤ X ├┤ U3(0,0,0.025) ├┤ X ├»
# «     └───────────────┘└─┬─┘└────────────────┘     └─┬─┘└───────────────┘└─┬─┘»
# «q_1: ───────────────────┼───────────────────────────┼─────────────────────┼──»
# «                        │  ┌────────────────┐┌───┐  │                     │  »
# «q_2: ───────────────────■──┤ U3(0,π/2,-π/2) ├┤ X ├──■─────────────────────■──»
# «                           └────────────────┘└─┬─┘                           »
# «q_3: ──────────────────────────────────────────■─────────────────────────────»
# «                                                                             »
# «     ┌────────────────┐                    ┌───┐┌──────────────┐┌───┐     »
# «q_0: ┤ U3(π/2,π/2,-π) ├────────────────────┤ X ├┤ U3(0,0,0.05) ├┤ X ├─────»
# «     └────────────────┘               ┌───┐└─┬─┘└──────────────┘└─┬─┘┌───┐»
# «q_1: ─────────────────────────────────┤ X ├──■────────────────────■──┤ X ├»
# «           ┌───┐       ┌─────────────┐└─┬─┘                          └─┬─┘»
# «q_2: ──────┤ X ├───────┤ U3(π/2,0,π) ├──■──────────────────────────────■──»
# «           └─┬─┘       └─────────────┘                                    »
# «q_3: ────────■────────────────────────────────────────────────────────────»
# «                                                                          »
# «                                                                        ┌───┐»
# «q_0: ───────────────────────────────────────────────────────────────────┤ X ├»
# «     ┌────────────────┐┌───┐┌──────────────┐┌───┐┌────────────────┐┌───┐└─┬─┘»
# «q_1: ┤ U3(0,π/2,-π/2) ├┤ X ├┤ U3(0,0,-0.1) ├┤ X ├┤ U3(0,π/2,-π/2) ├┤ X ├──■──»
# «     └────────────────┘└─┬─┘└──────────────┘└─┬─┘└────────────────┘└─┬─┘     »
# «q_2: ────────────────────┼────────────────────┼──────────────────────■───────»
# «                         │                    │                              »
# «q_3: ────────────────────■────────────────────■──────────────────────────────»
# «                                                                             »
# «     ┌──────────────┐┌───┐┌───────────────┐                       ┌───┐»
# «q_0: ┤ U3(0,0,0.05) ├┤ X ├┤ U3(π/2,0,π/2) ├───────────────────────┤ X ├»
# «     └──────────────┘└─┬─┘└─────┬───┬─────┘┌────────────────┐     └─┬─┘»
# «q_1: ──────────────────■────────┤ X ├──────┤ U3(π/2,π/2,-π) ├───────┼──»
# «                                └─┬─┘      └┬─────────────┬─┘┌───┐  │  »
# «q_2: ─────────────────────────────■─────────┤ U3(π/2,0,π) ├──┤ X ├──■──»
# «                                            └─────────────┘  └─┬─┘     »
# «q_3: ──────────────────────────────────────────────────────────■───────»
# «                                                                       »
# «     ┌───────────────┐┌───┐┌────────────────┐                  ┌───┐»
# «q_0: ┤ U3(0,0,0.025) ├┤ X ├┤ U3(0,π/2,-π/2) ├──────────────────┤ X ├»
# «     └───────────────┘└─┬─┘└────────────────┘                  └─┬─┘»
# «q_1: ───────────────────┼────────────────────────────────────────┼──»
# «                        │        ┌───┐       ┌────────────────┐  │  »
# «q_2: ───────────────────■────────┤ X ├───────┤ U3(0,π/2,-π/2) ├──■──»
# «                                 └─┬─┘       └────────────────┘     »
# «q_3: ──────────────────────────────■────────────────────────────────»
# «                                                                    »
# «     ┌───────────────┐┌───┐┌────────────────┐          ┌───┐┌───────────────┐»
# «q_0: ┤ U3(0,0,0.025) ├┤ X ├┤ U3(0,π/2,-π/2) ├──────────┤ X ├┤ U3(0,0,0.025) ├»
# «     └───────────────┘└─┬─┘└────────────────┘     ┌───┐└─┬─┘└───────────────┘»
# «q_1: ───────────────────┼─────────────────────────┤ X ├──■───────────────────»
# «                        │  ┌────────────────┐┌───┐└─┬─┘                      »
# «q_2: ───────────────────■──┤ U3(0,π/2,-π/2) ├┤ X ├──■────────────────────────»
# «                           └────────────────┘└─┬─┘                           »
# «q_3: ──────────────────────────────────────────■─────────────────────────────»
# «                                                                             »
# «     ┌───┐┌────────────────┐                            ┌───┐┌───────────────┐»
# «q_0: ┤ X ├┤ U3(0,π/2,-π/2) ├────────────────────────────┤ X ├┤ U3(0,0,0.025) ├»
# «     └─┬─┘└─────┬───┬──────┘                       ┌───┐└─┬─┘└───────────────┘»
# «q_1: ──■────────┤ X ├──────────────────────────────┤ X ├──■───────────────────»
# «                └─┬─┘       ┌───┐┌────────────────┐└─┬─┘                      »
# «q_2: ─────────────■─────────┤ X ├┤ U3(0,π/2,-π/2) ├──■────────────────────────»
# «                            └─┬─┘└────────────────┘                           »
# «q_3: ─────────────────────────■───────────────────────────────────────────────»
# «                                                                              »
# «     ┌───┐┌────────────────┐                         ┌───┐┌──────────────┐»
# «q_0: ┤ X ├┤ U3(0,π/2,-π/2) ├─────────────────────────┤ X ├┤ U3(0,0,0.05) ├»
# «     └─┬─┘└─────┬───┬──────┘ ┌───────────────┐  ┌───┐└─┬─┘└──────────────┘»
# «q_1: ──■────────┤ X ├────────┤ U3(π/2,0,π/2) ├──┤ X ├──■──────────────────»
# «                └─┬─┘       ┌┴───────────────┴─┐└─┬─┘                     »
# «q_2: ─────────────■─────────┤ U3(π/2,π/2,-π/2) ├──■───────────────────────»
# «                            └──────────────────┘                          »
# «q_3: ─────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «     ┌───┐┌──────────────────┐                       ┌───┐┌────────────────┐»
# «q_0: ┤ X ├┤ U3(π/2,-π/2,π/2) ├───────────────────────┤ X ├┤ U3(0,0,-0.025) ├»
# «     └─┬─┘└──────┬───┬───────┘┌────────────────┐     └─┬─┘└────────────────┘»
# «q_1: ──■─────────┤ X ├────────┤ U3(π/2,π/2,-π) ├───────┼────────────────────»
# «                 └─┬─┘        ├────────────────┤┌───┐  │                    »
# «q_2: ──────────────■──────────┤ U3(0,π/2,-π/2) ├┤ X ├──■────────────────────»
# «                              └────────────────┘└─┬─┘                       »
# «q_3: ─────────────────────────────────────────────■─────────────────────────»
# «                                                                            »
# «     ┌───┐┌────────────────┐                  ┌───┐┌────────────────┐┌───┐»
# «q_0: ┤ X ├┤ U3(0,π/2,-π/2) ├──────────────────┤ X ├┤ U3(0,0,-0.025) ├┤ X ├»
# «     └─┬─┘└────────────────┘                  └─┬─┘└────────────────┘└─┬─┘»
# «q_1: ──┼────────────────────────────────────────┼──────────────────────┼──»
# «       │        ┌───┐       ┌────────────────┐  │                      │  »
# «q_2: ──■────────┤ X ├───────┤ U3(0,π/2,-π/2) ├──■──────────────────────■──»
# «                └─┬─┘       └────────────────┘                            »
# «q_3: ─────────────■───────────────────────────────────────────────────────»
# «                                                                          »
# «     ┌────────────────┐          ┌───┐┌────────────────┐┌───┐»
# «q_0: ┤ U3(0,π/2,-π/2) ├──────────┤ X ├┤ U3(0,0,-0.025) ├┤ X ├»
# «     └────────────────┘     ┌───┐└─┬─┘└────────────────┘└─┬─┘»
# «q_1: ───────────────────────┤ X ├──■──────────────────────■──»
# «     ┌────────────────┐┌───┐└─┬─┘                            »
# «q_2: ┤ U3(0,π/2,-π/2) ├┤ X ├──■──────────────────────────────»
# «     └────────────────┘└─┬─┘                                 »
# «q_3: ────────────────────■───────────────────────────────────»
# «                                                             »
# «     ┌────────────────┐                            ┌───┐┌────────────────┐»
# «q_0: ┤ U3(0,π/2,-π/2) ├────────────────────────────┤ X ├┤ U3(0,0,-0.025) ├»
# «     └─────┬───┬──────┘                       ┌───┐└─┬─┘└────────────────┘»
# «q_1: ──────┤ X ├──────────────────────────────┤ X ├──■────────────────────»
# «           └─┬─┘       ┌───┐┌────────────────┐└─┬─┘                       »
# «q_2: ────────■─────────┤ X ├┤ U3(0,π/2,-π/2) ├──■─────────────────────────»
# «                       └─┬─┘└────────────────┘                            »
# «q_3: ────────────────────■────────────────────────────────────────────────»
# «                                                                          »
# «     ┌───┐┌────────────────┐                         ┌───┐┌──────────────┐»
# «q_0: ┤ X ├┤ U3(0,π/2,-π/2) ├─────────────────────────┤ X ├┤ U3(0,0,0.05) ├»
# «     └─┬─┘└─────┬───┬──────┘ ┌───────────────┐  ┌───┐└─┬─┘└──────────────┘»
# «q_1: ──■────────┤ X ├────────┤ U3(π/2,0,π/2) ├──┤ X ├──■──────────────────»
# «                └─┬─┘       ┌┴───────────────┴─┐└─┬─┘                     »
# «q_2: ─────────────■─────────┤ U3(π/2,-π/2,π/2) ├──■───────────────────────»
# «                            └──────────────────┘                          »
# «q_3: ─────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «     ┌───┐┌─────────────┐
# «q_0: ┤ X ├┤ U3(π/2,0,π) ├──────────────────
# «     └─┬─┘└────┬───┬────┘┌────────────────┐
# «q_1: ──■───────┤ X ├─────┤ U3(π/2,π/2,-π) ├
# «               └─┬─┘     └┬─────────────┬─┘
# «q_2: ────────────■────────┤ U3(π/2,0,π) ├──
# «                          └─────────────┘
# «q_3: ──────────────────────────────────────
# «

# %% [markdown]
# Effect of Fermion to Qubit Mapping
# -----------------------------------------
#
# The mapping has to encode the positions of the electrons and do so with a guarantee of anti-symmetry of the fermionic wave functions, to respect fermion algebra. There are thus two pieces of information: the electron occupancy on each site and the overall parity. The Jordan-Wigner mapping fully localizes the occupation number (each qubit represents the occupation on a site), which then causes the parity to be completely non-localized: whenever an electron "hops" sites, the parity update requires an update to all qubits, propagated through a chain of controlled gates. The Bravyi-Kitaev transform encodes both occupancy and parity information non-locally, leading to a more balanced result.
#
# **Exercise:** Check the circuits again and find that the Jordan-Wigner mapping results in many more series of CNOTs involving all qubits than does Bravyi-Kitaev. These series of CNOTs across all qubits are a worst-case scenario for synthesis, as they prevent further partitioning and are already optimal.
#
# <div class="alert alert-block alert-info">
# <b>Note:</b> the circuits above were generated using the same number of Trotter steps (a method of approximating an exponential) and although the Bravyi-Kitaev circuit is significantly shorter in that case, the approximation is actually slightly worse. After adjusting the number of steps and the method to achieve the same quality of approximation (use <tt>trotter_steps=2, trotter_mode='trotter'</tt> for Jordan-Wigner and <tt>trotter_steps=3, trotter_mode='trotter'</tt>), both methods are much closer in the number of CNOTs in the unoptimized circuit. Since Trotter steps are just repetitions, this does not change any conclusions about the relative effectiveness of BQSKit's circuit synthesis on the respective mappings.
# </div>

# %% [markdown]
# **Exercise:** Use what you learned in the __[BQSKit introductory notebook](1_comping_with_bqskit.ipynb)__ to compile both circuit instances. Try for `optimization_level=2` and `max_synthesis_size=3` first, adjust and play with the parameters if time allows (do note that larger block size and/or higher optimization level can result in significantly longer compilation times). Compare and explain the results.
#
# **Optional exercise:** The examples so far have presumed all-to-all. Experiment with one of the realistic QPU models, or your own. Are the results and conclusions the same?

# %%
circuits = ((c_jw, 'Jordan-Wigner'), (c_bk, 'Bravyi-Kitaev'))

for circuit, mapping in circuits:
    opt_circuit = bqskit.compile(qiskit_to_bqskit(circuit), optimization_level=2, max_synthesis_size=3)

    # Print new circuit statistics
    print("Compiled Circuit Statistics for:", mapping)
    print("  Gate Counts:", opt_circuit.gate_counts)
    print("  Connectivity:", opt_circuit.coupling_graph)
# Out:
# Compiled Circuit Statistics for: Jordan-Wigner
#   Gate Counts: {CNOTGate: 104, U3Gate: 98}
#   Connectivity: CouplingGraph({(2, 3), (1, 2), (0, 1)})
# Compiled Circuit Statistics for: Bravyi-Kitaev
#   Gate Counts: {CNOTGate: 63, U3Gate: 90}
#   Connectivity: CouplingGraph({(0, 1), (1, 2), (2, 3), (0, 2), (1, 3)})

# %% [markdown]
# Variational Quantum Eigensolver
# --------------------------------------
#
# In the VQE algorithm, circuits are synthesized based on parameters provided by a classical minimizer. All we need to do, is to pass the energy objective function to a classical optimizer. Since we are not considering noise here (see the [scikit-quant tutorials](https://github.com/scikit-quant/scikit-quant/tree/master/tutorials), if interested), most any optimizer will do. Here, we will use [BFGS from SciPy](https://docs.scipy.org/doc/scipy/reference/optimize.html#module-scipy.optimize).

# %%
min_energy = scipy.optimize.minimize(jw_objective, [0.1]*jw_objective.npar(), method='BFGS')
print("minimum energy: %.5f (exact: %.5f)" % (min_energy.fun, hubbard.exact(hm_jw, **hm_filling)))
# Out:
# minimum energy: -1.00000 (exact: -1.00000)

# %% [markdown]
# **Exercise:** Verify the results for the objective using the Bravyi-Kitaev mapping. Optionally, try different fillings and grid sizes (note that larger grids will have local minima where the optimizer can get stuck if not seeded close to the global minimum).

# %%
min_energy = scipy.optimize.minimize(bk_objective, [0.1]*bk_objective.npar(), method='BFGS')
print("minimum energy: %.5f (exact: %.5f)" % (min_energy.fun, hubbard.exact(hm_bk, **hm_filling)))
# Out:
# minimum energy: -1.00000 (exact: -1.00000)

# %% [markdown]
# The Ansatz forms the bulk of any VQE circuit: both the input state and the Hamiltonian components only require single qubit rotations, at most, at the beginning and at the very end to measure the desired projection components for each qubit.
# It thus makes sense to optimize the Ansatz part of the circuit independently and re-use it (with at most a fast peep-hole pass to merge single qubit gates at start and end where possible).
#
# **Exercise:** The `EnergyObjective` is written such that a derived class can implement the `bqskit` optimization. Fill in the remainder below, and verify the results. Use the added pass to collect statistics on the `bqskit` results.

# %%
from hubbard import EnergyObjective

# to show BQSKit is running
bqskit.enable_logging()

class MyObjective(EnergyObjective):
    def optimize_evolution(self, bqskit_circuit):
        return bqskit.compile(
            bqskit_circuit,
            optimization_level=2,
            max_synthesis_size=3,
        )
    
bk_objective = MyObjective(hm_bk, **hm_filling)
start = timer()
min_energy = scipy.optimize.minimize(bk_objective, [0.1]*bk_objective.npar(), method='BFGS')
print("converged in %.0f seconds" % (timer() - start))
print("minimum energy: %.5f (exact: %.5f)" % (min_energy.fun, hubbard.exact(hm_bk, **hm_filling)))
# Out:
# 10:31:35.072 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=23]
# 10:31:35.073 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=23]
# 10:31:36.588 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=23]
# 10:31:36.588 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=23]
# 10:31:36.609 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=23]
# 10:31:36.633 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=23]
# 10:31:36.634 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=23]
# 10:31:37.818 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=23]
# 10:31:39.936 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=23]
# 10:31:39.945 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=23]
# 10:31:41.709 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=114]
# 10:31:41.711 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=114]
# 10:31:42.855 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=114]
# 10:31:42.855 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=114]
# 10:31:42.876 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=114]
# 10:31:42.900 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=114]
# 10:31:42.900 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=114]
# 10:31:44.506 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=114]
# 10:31:46.974 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=114]
# 10:31:46.983 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=114]
# 10:31:48.760 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=67]
# 10:31:48.762 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=67]
# 10:31:50.415 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=67]
# 10:31:50.415 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=67]
# 10:31:50.437 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=67]
# 10:31:50.461 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=67]
# 10:31:50.461 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=67]
# 10:31:52.137 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=67]
# 10:31:53.754 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=67]
# 10:31:53.763 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=67]
# 10:31:55.541 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=117]
# 10:31:55.542 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=117]
# 10:31:56.852 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=117]
# 10:31:56.852 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=117]
# 10:31:56.873 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=117]
# 10:31:56.898 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=117]
# 10:31:56.898 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=117]
# 10:31:58.278 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=117]
# 10:32:00.591 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=117]
# 10:32:00.601 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=117]
# 10:32:02.401 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=37]
# 10:32:02.403 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=37]
# 10:32:03.633 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=37]
# 10:32:03.633 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=37]
# 10:32:03.655 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=37]
# 10:32:03.680 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=37]
# 10:32:03.680 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=37]
# 10:32:04.955 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=37]
# 10:32:06.693 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=37]
# 10:32:06.702 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=37]
# 10:32:08.379 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=21]
# 10:32:08.380 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=21]
# 10:32:09.603 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=21]
# 10:32:09.603 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=21]
# 10:32:09.625 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=21]
# 10:32:09.650 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=21]
# 10:32:09.650 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=21]
# 10:32:10.763 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=21]
# 10:32:12.544 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=21]
# 10:32:12.555 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=21]
# 10:32:14.363 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=116]
# 10:32:14.364 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=116]
# 10:32:15.901 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=116]
# 10:32:15.901 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=116]
# 10:32:15.923 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=116]
# 10:32:15.955 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=116]
# 10:32:15.956 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=116]
# 10:32:17.568 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=116]
# 10:32:20.412 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=116]
# 10:32:20.421 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=116]
# 10:32:22.223 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=81]
# 10:32:22.224 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=81]
# 10:32:23.826 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=81]
# 10:32:23.826 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=81]
# 10:32:23.848 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=81]
# 10:32:23.873 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=81]
# 10:32:23.874 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=81]
# 10:32:25.177 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=81]
# 10:32:29.689 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=81]
# 10:32:29.698 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=81]
# 10:32:31.493 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=54]
# 10:32:31.495 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=54]
# 10:32:33.106 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=54]
# 10:32:33.106 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=54]
# 10:32:33.137 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=54]
# 10:32:33.163 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=54]
# 10:32:33.163 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=54]
# 10:32:34.383 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=54]
# 10:32:36.976 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=54]
# 10:32:36.986 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=54]
# 10:32:38.785 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=23]
# 10:32:38.786 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=23]
# 10:32:40.141 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=23]
# 10:32:40.141 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=23]
# 10:32:40.163 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=23]
# 10:32:40.188 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=23]
# 10:32:40.188 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=23]
# 10:32:41.242 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=23]
# 10:32:49.297 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=23]
# 10:32:49.307 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=23]
# 10:32:51.102 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=75]
# 10:32:51.104 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=75]
# 10:32:52.642 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=75]
# 10:32:52.642 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=75]
# 10:32:52.664 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=75]
# 10:32:52.689 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=75]
# 10:32:52.689 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=75]
# 10:32:53.748 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=75]
# 10:32:55.047 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=75]
# 10:32:55.057 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=75]
# 10:32:56.837 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=97]
# 10:32:56.839 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=97]
# 10:32:58.276 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=97]
# 10:32:58.276 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=97]
# 10:32:58.297 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=97]
# 10:32:58.322 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=97]
# 10:32:58.322 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=97]
# 10:32:59.538 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=97]
# 10:33:01.426 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=97]
# 10:33:01.435 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=97]
# 10:33:03.235 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=24]
# 10:33:03.236 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=24]
# 10:33:04.501 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=24]
# 10:33:04.501 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=24]
# 10:33:04.522 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=24]
# 10:33:04.545 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=24]
# 10:33:04.545 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=24]
# 10:33:05.661 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=24]
# 10:33:07.280 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=24]
# 10:33:07.289 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=24]
# 10:33:09.062 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=63]
# 10:33:09.064 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=63]
# 10:33:10.354 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=63]
# 10:33:10.354 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=63]
# 10:33:10.376 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=63]
# 10:33:10.401 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=63]
# 10:33:10.402 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=63]
# 10:33:11.476 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=63]
# 10:33:13.118 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=63]
# 10:33:13.127 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=63]
# 10:33:14.908 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=4]
# 10:33:14.909 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=4]
# 10:33:16.514 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=4]
# 10:33:16.514 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=4]
# 10:33:16.536 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=4]
# 10:33:16.561 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=4]
# 10:33:16.561 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=4]
# 10:33:17.763 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=4]
# 10:33:18.945 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=4]
# 10:33:18.954 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=4]
# 10:33:20.753 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=67]
# 10:33:20.754 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=67]
# 10:33:22.030 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=67]
# 10:33:22.030 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=67]
# 10:33:22.052 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=67]
# 10:33:22.076 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=67]
# 10:33:22.076 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=67]
# 10:33:23.161 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=67]
# 10:33:24.898 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=67]
# 10:33:24.908 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=67]
# 10:33:26.695 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=120]
# 10:33:26.696 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=120]
# 10:33:28.499 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=120]
# 10:33:28.499 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=120]
# 10:33:28.521 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=120]
# 10:33:28.546 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=120]
# 10:33:28.546 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=120]
# 10:33:29.552 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=120]
# 10:33:30.998 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=120]
# 10:33:31.008 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=120]
# 10:33:32.812 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=0]
# 10:33:32.814 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=0]
# 10:33:34.166 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=0]
# 10:33:34.166 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=0]
# 10:33:34.188 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=0]
# 10:33:34.213 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=0]
# 10:33:34.213 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=0]
# 10:33:35.349 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=0]
# 10:33:37.655 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=0]
# 10:33:37.665 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=0]
# 10:33:39.482 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=117]
# 10:33:39.483 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=117]
# 10:33:40.831 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=117]
# 10:33:40.831 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=117]
# 10:33:40.854 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=117]
# 10:33:40.879 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=117]
# 10:33:40.880 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=117]
# 10:33:42.086 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=117]
# 10:33:44.276 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=117]
# 10:33:44.286 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=117]
# 10:33:46.102 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=90]
# 10:33:46.103 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=90]
# 10:33:47.788 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=90]
# 10:33:47.788 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=90]
# 10:33:47.810 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=90]
# 10:33:47.834 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=90]
# 10:33:47.834 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=90]
# 10:33:49.320 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=90]
# 10:33:51.131 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=90]
# 10:33:51.141 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=90]
# 10:33:52.938 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=5]
# 10:33:52.940 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=5]
# 10:33:54.171 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=5]
# 10:33:54.171 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=5]
# 10:33:54.194 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=5]
# 10:33:54.219 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=5]
# 10:33:54.219 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=5]
# 10:33:55.311 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=5]
# 10:33:57.033 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=5]
# 10:33:57.043 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=5]
# 10:33:58.944 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=5]
# 10:33:58.945 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=5]
# 10:34:00.203 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=5]
# 10:34:00.203 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=5]
# 10:34:00.225 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=5]
# 10:34:00.249 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=5]
# 10:34:00.249 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=5]
# 10:34:01.331 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=5]
# 10:34:02.874 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=5]
# 10:34:02.883 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=5]
# 10:34:04.669 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=53]
# 10:34:04.671 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=53]
# 10:34:06.109 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=53]
# 10:34:06.109 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=53]
# 10:34:06.130 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=53]
# 10:34:06.153 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=53]
# 10:34:06.153 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=53]
# 10:34:07.294 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=53]
# 10:34:09.166 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=53]
# 10:34:09.175 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=53]
# 10:34:10.966 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=21]
# 10:34:10.967 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=21]
# 10:34:12.241 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=21]
# 10:34:12.241 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=21]
# 10:34:12.263 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=21]
# 10:34:12.287 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=21]
# 10:34:12.287 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=21]
# 10:34:13.317 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=21]
# 10:34:14.710 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=21]
# 10:34:14.720 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=21]
# 10:34:16.529 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=43]
# 10:34:16.530 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=43]
# 10:34:17.804 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=43]
# 10:34:17.804 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=43]
# 10:34:17.825 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=43]
# 10:34:17.849 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=43]
# 10:34:17.849 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=43]
# 10:34:19.299 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=43]
# 10:34:21.349 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=43]
# 10:34:21.358 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=43]
# 10:34:23.137 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=112]
# 10:34:23.139 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=112]
# 10:34:24.547 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=112]
# 10:34:24.547 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=112]
# 10:34:24.570 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=112]
# 10:34:24.596 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=112]
# 10:34:24.596 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=112]
# 10:34:25.781 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=112]
# 10:34:27.279 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=112]
# 10:34:27.289 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=112]
# 10:34:29.098 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=91]
# 10:34:29.099 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=91]
# 10:34:30.509 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=91]
# 10:34:30.509 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=91]
# 10:34:30.529 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=91]
# 10:34:30.552 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=91]
# 10:34:30.552 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=91]
# 10:34:31.900 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=91]
# 10:34:33.627 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=91]
# 10:34:33.636 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=91]
# 10:34:35.406 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=71]
# 10:34:35.407 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=71]
# 10:34:36.702 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=71]
# 10:34:36.702 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=71]
# 10:34:36.724 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=71]
# 10:34:36.749 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=71]
# 10:34:36.749 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=71]
# 10:34:37.958 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=71]
# 10:34:39.558 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=71]
# 10:34:39.568 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=71]
# 10:34:41.371 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=53]
# 10:34:41.372 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=53]
# 10:34:42.731 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=53]
# 10:34:42.731 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=53]
# 10:34:42.753 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=53]
# 10:34:42.777 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=53]
# 10:34:42.777 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=53]
# 10:34:43.912 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=53]
# 10:34:45.641 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=53]
# 10:34:45.650 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=53]
# 10:34:47.445 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=73]
# 10:34:47.446 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=73]
# 10:34:48.900 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=73]
# 10:34:48.900 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=73]
# 10:34:48.923 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=73]
# 10:34:48.948 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=73]
# 10:34:48.949 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=73]
# 10:34:50.210 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=73]
# 10:34:52.469 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=73]
# 10:34:52.479 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=73]
# 10:34:54.330 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=106]
# 10:34:54.332 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=106]
# 10:34:55.738 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=106]
# 10:34:55.738 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=106]
# 10:34:55.759 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=106]
# 10:34:55.784 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=106]
# 10:34:55.784 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=106]
# 10:34:56.929 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=106]
# 10:34:59.100 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=106]
# 10:34:59.109 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=106]
# 10:35:00.915 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=24]
# 10:35:00.916 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=24]
# 10:35:02.224 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=24]
# 10:35:02.224 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=24]
# 10:35:02.246 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=24]
# 10:35:02.270 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=24]
# 10:35:02.271 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=24]
# 10:35:03.524 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=24]
# 10:35:05.647 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=24]
# 10:35:05.657 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=24]
# 10:35:07.437 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=75]
# 10:35:07.439 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=75]
# 10:35:08.730 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=75]
# 10:35:08.730 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=75]
# 10:35:08.753 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=75]
# 10:35:08.778 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=75]
# 10:35:08.778 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=75]
# 10:35:09.948 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=75]
# 10:35:11.651 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=75]
# 10:35:11.660 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=75]
# 10:35:13.427 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=73]
# 10:35:13.429 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=73]
# 10:35:14.721 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=73]
# 10:35:14.721 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=73]
# 10:35:14.743 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=73]
# 10:35:14.768 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=73]
# 10:35:14.769 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=73]
# 10:35:16.150 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=73]
# 10:35:18.350 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=73]
# 10:35:18.359 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=73]
# 10:35:20.148 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=43]
# 10:35:20.149 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=43]
# 10:35:21.603 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=43]
# 10:35:21.603 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=43]
# 10:35:21.625 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=43]
# 10:35:21.650 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=43]
# 10:35:21.650 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=43]
# 10:35:22.591 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=43]
# 10:35:23.879 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=43]
# 10:35:23.890 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=43]
# 10:35:25.683 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=64]
# 10:35:25.684 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=64]
# 10:35:27.090 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=64]
# 10:35:27.091 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=64]
# 10:35:27.112 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=64]
# 10:35:27.137 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=64]
# 10:35:27.137 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=64]
# 10:35:29.068 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=64]
# 10:35:30.415 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=64]
# 10:35:30.424 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=64]
# 10:35:32.221 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=44]
# 10:35:32.222 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=44]
# 10:35:33.464 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=44]
# 10:35:33.465 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=44]
# 10:35:33.487 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=44]
# 10:35:33.512 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=44]
# 10:35:33.512 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=44]
# 10:35:34.637 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=44]
# 10:35:37.416 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=44]
# 10:35:37.425 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=44]
# 10:35:39.216 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=111]
# 10:35:39.217 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=111]
# 10:35:40.598 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=111]
# 10:35:40.598 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=111]
# 10:35:40.619 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=111]
# 10:35:40.643 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=111]
# 10:35:40.643 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=111]
# 10:35:41.837 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=111]
# 10:35:43.282 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=111]
# 10:35:43.292 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=111]
# 10:35:45.205 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=53]
# 10:35:45.207 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=53]
# 10:35:46.586 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=53]
# 10:35:46.586 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=53]
# 10:35:46.608 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=53]
# 10:35:46.633 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=53]
# 10:35:46.634 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=53]
# 10:35:47.715 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=53]
# 10:35:49.238 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=53]
# 10:35:49.247 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=53]
# 10:35:51.062 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=37]
# 10:35:51.064 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=37]
# 10:35:52.364 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=37]
# 10:35:52.364 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=37]
# 10:35:52.386 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=37]
# 10:35:52.411 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=37]
# 10:35:52.411 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=37]
# 10:35:53.719 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=37]
# 10:35:55.927 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=37]
# 10:35:55.937 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=37]
# 10:35:57.741 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=113]
# 10:35:57.743 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=113]
# 10:35:59.136 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=113]
# 10:35:59.136 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=113]
# 10:35:59.157 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=113]
# 10:35:59.182 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=113]
# 10:35:59.182 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=113]
# 10:36:00.253 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=113]
# 10:36:01.735 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=113]
# 10:36:01.744 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=113]
# 10:36:03.543 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=19]
# 10:36:03.544 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=19]
# 10:36:04.794 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=19]
# 10:36:04.794 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=19]
# 10:36:04.815 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=19]
# 10:36:04.840 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=19]
# 10:36:04.840 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=19]
# 10:36:06.733 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=19]
# 10:36:09.186 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=19]
# 10:36:09.195 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=19]
# 10:36:11.008 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=23]
# 10:36:11.010 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=23]
# 10:36:12.467 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=23]
# 10:36:12.467 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=23]
# 10:36:12.488 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=23]
# 10:36:12.511 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=23]
# 10:36:12.512 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=23]
# 10:36:13.689 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=23]
# 10:36:15.441 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=23]
# 10:36:15.451 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=23]
# 10:36:17.227 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=127]
# 10:36:17.229 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=127]
# 10:36:18.618 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=127]
# 10:36:18.618 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=127]
# 10:36:18.640 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=127]
# 10:36:18.664 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=127]
# 10:36:18.665 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=127]
# 10:36:19.859 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=127]
# 10:36:22.927 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=127]
# 10:36:22.936 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=127]
# 10:36:24.722 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=61]
# 10:36:24.724 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=61]
# 10:36:26.096 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=61]
# 10:36:26.096 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=61]
# 10:36:26.116 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=61]
# 10:36:26.140 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=61]
# 10:36:26.140 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=61]
# 10:36:27.447 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=61]
# 10:36:30.001 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=61]
# 10:36:30.011 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=61]
# 10:36:31.795 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=55]
# 10:36:31.797 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=55]
# 10:36:33.124 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=55]
# 10:36:33.125 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=55]
# 10:36:33.146 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=55]
# 10:36:33.171 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=55]
# 10:36:33.171 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=55]
# 10:36:34.636 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=55]
# 10:36:36.064 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=55]
# 10:36:36.073 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=55]
# 10:36:37.860 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=56]
# 10:36:37.862 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=56]
# 10:36:39.147 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=56]
# 10:36:39.147 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=56]
# 10:36:39.169 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=56]
# 10:36:39.194 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=56]
# 10:36:39.194 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=56]
# 10:36:40.578 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=56]
# 10:36:42.565 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=56]
# 10:36:42.574 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=56]
# 10:36:44.375 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=72]
# 10:36:44.376 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=72]
# 10:36:45.731 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=72]
# 10:36:45.731 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=72]
# 10:36:45.753 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=72]
# 10:36:45.779 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=72]
# 10:36:45.779 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=72]
# 10:36:46.949 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=72]
# 10:36:48.530 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=72]
# 10:36:48.540 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=72]
# 10:36:50.332 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=49]
# 10:36:50.333 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=49]
# 10:36:51.781 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=49]
# 10:36:51.781 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=49]
# 10:36:51.803 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=49]
# 10:36:51.828 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=49]
# 10:36:51.828 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=49]
# 10:36:52.974 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=49]
# 10:36:55.047 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=49]
# 10:36:55.057 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=49]
# 10:36:56.855 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=106]
# 10:36:56.856 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=106]
# 10:36:58.281 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=106]
# 10:36:58.281 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=106]
# 10:36:58.308 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=106]
# 10:36:58.334 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=106]
# 10:36:58.334 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=106]
# 10:36:59.578 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=106]
# 10:37:01.501 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=106]
# 10:37:01.511 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=106]
# 10:37:03.317 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=56]
# 10:37:03.318 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=56]
# 10:37:04.632 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=56]
# 10:37:04.632 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=56]
# 10:37:04.653 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=56]
# 10:37:04.677 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=56]
# 10:37:04.677 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=56]
# 10:37:05.859 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=56]
# 10:37:08.412 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=56]
# 10:37:08.422 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=56]
# 10:37:10.205 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=83]
# 10:37:10.207 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=83]
# 10:37:11.566 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=83]
# 10:37:11.566 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=83]
# 10:37:11.589 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=83]
# 10:37:11.614 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=83]
# 10:37:11.614 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=83]
# 10:37:12.784 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=83]
# 10:37:14.846 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=83]
# 10:37:14.856 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=83]
# 10:37:16.655 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=0]
# 10:37:16.657 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=0]
# 10:37:17.950 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=0]
# 10:37:17.951 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=0]
# 10:37:17.972 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=0]
# 10:37:17.997 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=0]
# 10:37:17.997 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=0]
# 10:37:19.313 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=0]
# 10:37:21.253 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=0]
# 10:37:21.262 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=0]
# 10:37:23.171 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=24]
# 10:37:23.172 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=24]
# 10:37:24.571 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=24]
# 10:37:24.571 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=24]
# 10:37:24.592 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=24]
# 10:37:24.616 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=24]
# 10:37:24.616 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=24]
# 10:37:25.782 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=24]
# 10:37:27.303 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=24]
# 10:37:27.313 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=24]
# 10:37:29.086 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=117]
# 10:37:29.087 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=117]
# 10:37:30.629 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=117]
# 10:37:30.629 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=117]
# 10:37:30.651 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=117]
# 10:37:30.677 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=117]
# 10:37:30.677 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=117]
# 10:37:31.820 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=117]
# 10:37:33.683 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=117]
# 10:37:33.692 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=117]
# 10:37:35.488 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=48]
# 10:37:35.489 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=48]
# 10:37:36.989 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=48]
# 10:37:36.989 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=48]
# 10:37:37.020 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=48]
# 10:37:37.045 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=48]
# 10:37:37.045 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=48]
# 10:37:38.524 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=48]
# 10:37:40.042 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=48]
# 10:37:40.052 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=48]
# 10:37:41.819 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=51]
# 10:37:41.820 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=51]
# 10:37:43.271 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=51]
# 10:37:43.271 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=51]
# 10:37:43.292 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=51]
# 10:37:43.316 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=51]
# 10:37:43.316 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=51]
# 10:37:44.580 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=51]
# 10:37:47.891 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=51]
# 10:37:47.901 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=51]
# 10:37:49.661 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=121]
# 10:37:49.663 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=121]
# 10:37:51.057 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=121]
# 10:37:51.057 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=121]
# 10:37:51.079 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=121]
# 10:37:51.103 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=121]
# 10:37:51.104 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=121]
# 10:37:52.256 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=121]
# 10:37:53.879 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=121]
# 10:37:53.888 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=121]
# 10:37:55.681 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=38]
# 10:37:55.682 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=38]
# 10:37:57.015 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=38]
# 10:37:57.015 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=38]
# 10:37:57.039 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=38]
# 10:37:57.065 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=38]
# 10:37:57.065 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=38]
# 10:37:58.366 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=38]
# 10:38:00.512 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=38]
# 10:38:00.522 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=38]
# 10:38:02.299 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=70]
# 10:38:02.301 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=70]
# 10:38:03.943 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=70]
# 10:38:03.943 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=70]
# 10:38:03.964 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=70]
# 10:38:03.988 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=70]
# 10:38:03.989 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=70]
# 10:38:05.145 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=70]
# 10:38:08.075 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=70]
# 10:38:08.085 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=70]
# 10:38:09.772 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=62]
# 10:38:09.773 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=62]
# 10:38:11.238 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=62]
# 10:38:11.238 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=62]
# 10:38:11.259 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=62]
# 10:38:11.284 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=62]
# 10:38:11.284 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=62]
# 10:38:12.302 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=62]
# 10:38:14.381 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=62]
# 10:38:14.391 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=62]
# 10:38:16.161 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=95]
# 10:38:16.163 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=95]
# 10:38:17.522 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=95]
# 10:38:17.522 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=95]
# 10:38:17.553 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=95]
# 10:38:17.579 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=95]
# 10:38:17.579 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=95]
# 10:38:18.880 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=95]
# 10:38:20.473 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=95]
# 10:38:20.483 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=95]
# 10:38:22.272 - INFO     | bqskit.passes.measure: Extracting measurements from circuit. [wid=83]
# 10:38:22.273 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=83]
# 10:38:23.597 - INFO     | bqskit.passes.util.log: Mapping circuit. [wid=83]
# 10:38:23.597 - INFO     | bqskit.passes.mapping.placement.greedy: Placed qudits on [0, 1, 2, 3] [wid=83]
# 10:38:23.618 - INFO     | bqskit.passes.mapping.layout.sabre: Found layout: [0, 1, 2, 3], new placement: [0, 1, 2, 3] [wid=83]
# 10:38:23.641 - INFO     | bqskit.passes.mapping.routing.sabre: Finished routing with layout: [0, 1, 2, 3] [wid=83]
# 10:38:23.642 - INFO     | bqskit.passes.util.log: Retargeting multi-qudit gates. [wid=83]
# 10:38:25.248 - INFO     | bqskit.passes.util.log: Attempting to delete gates. [wid=83]
# 10:38:26.981 - INFO     | bqskit.passes.util.log: Upper bound on error is 0.0. [wid=83]
# 10:38:26.991 - INFO     | bqskit.passes.measure: Restoring measurements to circuit. [wid=83]
# converged in 414 seconds
# minimum energy: -1.00000 (exact: -1.00000)

# %% [markdown]
# ## Customizing Compilation for Better and Faster Workflows
# -----------------------------
#
# It is often useful to customize the compilation workflow that is set up by the `compile()` function, either because there are specific BQSKit tools you want to use, because you want to fine-tune settings, or simply because you want to add diagnostics to understand the synthesis performance better.
# In BQSKit, a [`Workflow`](https://bqskit.readthedocs.io/en/latest/source/autogen/bqskit.compiler.Workflow.html#bqskit.compiler.Workflow) object consists of a list of compilation passes executed in order. You can compile a circuit with a `Workflow` using a [`Compiler`](https://bqskit.readthedocs.io/en/latest/source/autogen/bqskit.compiler.Compiler.html#bqskit.compiler.Compiler) object, which handles the parallel execution environment. The off-the-shelf `compile()` function builds and executes a default workflow transparently. Let's take a look at this default workflow:

# %%
from bqskit.compiler.compile import build_workflow

default_opt1_workflow = build_workflow(qiskit_to_bqskit(c_jw), optimization_level=1)
print(default_opt1_workflow)
# Out:
# Workflow: Off-the-Shelf Circuit Compilation
# 	0. Workflow: UnfoldPass
# 	1. Workflow: ExtractMeasurements
# 	2. Workflow: SetModelPass
# 	3. Workflow: Multi Qudit Retargeting
# 	4. Workflow: SABRE Mapping
# 	5. Workflow: Multi Qudit Retargeting
# 	6. Workflow: Single Qudit Retargeting
# 	7. Workflow: LogErrorPass
# 	8. Workflow: ApplyPlacement
# 	9. Workflow: RestoreMeasurements

# %% [markdown]
# **Exercise:** Higher optimization workflows will, by definition, include more optimizations. Print out the workflows for higher optimization levels and identify the differences in the space below:

# %%
print(build_workflow(qiskit_to_bqskit(c_jw), optimization_level=2))
print(build_workflow(qiskit_to_bqskit(c_jw), optimization_level=3))
print(build_workflow(qiskit_to_bqskit(c_jw), optimization_level=4))
# Out:
# Workflow: Off-the-Shelf Circuit Compilation
# 	0. Workflow: UnfoldPass
# 	1. Workflow: ExtractMeasurements
# 	2. Workflow: SetModelPass
# 	3. Workflow: Multi Qudit Retargeting
# 	4. Workflow: SABRE Mapping
# 	5. Workflow: Multi Qudit Retargeting
# 	6. Workflow: Single Qudit Retargeting
# 	7. Workflow: Gate Deletion Optimization
# 	8. Workflow: LogErrorPass
# 	9. Workflow: ApplyPlacement
# 	10. Workflow: RestoreMeasurements
# Workflow: Off-the-Shelf Circuit Compilation
# 	0. Workflow: UnfoldPass
# 	1. Workflow: ExtractMeasurements
# 	2. Workflow: SetModelPass
# 	3. Workflow: Multi Qudit Retargeting
# 	4. Workflow: SABRE Mapping
# 	5. Workflow: Multi Qudit Retargeting
# 	6. Workflow: Iterative Resynthesis Optimization
# 	7. Workflow: Single Qudit Retargeting
# 	8. Workflow: Iterative Gate Deletion Optimization
# 	9. Workflow: LogErrorPass
# 	10. Workflow: ApplyPlacement
# 	11. Workflow: RestoreMeasurements
# Workflow: Off-the-Shelf Circuit Compilation
# 	0. Workflow: UnfoldPass
# 	1. Workflow: ExtractMeasurements
# 	2. Workflow: SetModelPass
# 	3. Workflow: SeqPAM Mapping
# 	4. Workflow: Multi Qudit Retargeting
# 	5. Workflow: Iterative Resynthesis Optimization
# 	6. Workflow: Single Qudit Retargeting
# 	7. Workflow: Iterative Gate Deletion Optimization
# 	8. Workflow: LogErrorPass
# 	9. Workflow: RestoreMeasurements

# %% [markdown]
# These default workflows are multi-faceted because they must deal with arbitrary input and work well in any situation.
# This necessity is not there when designing custom workflows as we often know great detail about our problem that we can exploit,
# leading to more straightforward, faster, and often higher-quality compilation workflows.
#
# The most common paradigm in BQSKit is to:
#
# 1. Partition a circuit
# 2. Do something on each partition
# 3. Unpartition (unfold) the circuit
#
# For example:

# %%
from bqskit.compiler import Workflow
from bqskit.passes import QuickPartitioner, ForEachBlockPass, ScanningGateRemovalPass, UnfoldPass

basic_gate_deletion_workflow = Workflow([
    QuickPartitioner(3),  # Partition into 3-qubit blocks
    ForEachBlockPass(ScanningGateRemovalPass()),  # Apply gate deletion to each block (in parallel)
    UnfoldPass(),  # Unfold the blocks back into the original circuit
])

# %% [markdown]
# The available passes are listed in the [documentation](https://bqskit.readthedocs.io/en/latest/source/passes.html). There are passes for partitioning, synthesis, conversions, iterative, conditionals, checkpointing, etc. etc. Of course, you can also write your own custom passes; see [this guide](https://bqskit.readthedocs.io/en/latest/guides/custompass.html) for more info.
#
# Once you have a `Workflow`, you can use the BQSKIt compiler to execute it on a circuit:

# %%
from bqskit.compiler import Compiler

with Compiler() as compiler:
    opt_circuit = compiler.compile(qiskit_to_bqskit(c_jw), workflow=basic_gate_deletion_workflow)

print(opt_circuit.gate_counts)
# Out:
# {CNOTGate: 124, U3Gate: 75}

# %% [markdown]
# **Exercise:** The `compile()` function uses the LEAP algorithm by default. Below are some example workflows to get started trying different partitioners and algorithms. Make sure to look up each pass in the [documentation](https://bqskit.readthedocs.io/en/latest/source/passes.html), and don't hesitate to try your own mix. Try them either with one of the earlier single circuits, or implement them in the `MyObjective` function from the previous exercise to use with a complete VQE run.
#
# ```
# from bqskit import MachineModel
# from bqskit.passes.mapping.setmodel import SetModelPass
# from bqskit.passes import *
#
# workflow = [
#     SetModelPass(model),
#     QuickPartitioner(),
#     ForEachBlockPass([
#         QSearchSynthesisPass(),
#         ScanningGateRemovalPass()
#     ]),
#     UnfoldPass()
# ]
# ```
#
# **Optional Exercise:** To improve your understanding, here are two possible diagnostic passes that can be inserted into the workflow to show/debug the effect of individual passes. Add them into your workflow as needed and/or create your own:
#
# ```
# from bqskit.compiler.basepass import BasePass
# from bqskit.ir.gates import CircuitGate, CNOTGate
# import logging
#
# enable_logging()
#
# _logger = logging.getLogger("bqskit.notebook")
#
# class PrintCNOTsPass(BasePass):
#     async def run(self, circuit, data) -> None:
#         _logger.info(f"BQSKit step, current CNOT count: {circuit.count(CNOTGate())}")
#
# class PrintPartitionInfoPass(BasePass):
#     async def run(self, circuit, data):
#         acm = 0
#         for op in circuit:
#             if not isinstance(op.gate, CircuitGate):
#                 _logger.info("Circuit not yet partitioned")
#                 return
#
#             acm += op.gate._circuit.num_operations
#
#         _logger.info(f"Number of partitions: {circuit.num_operations}")
#         _logger.info(f"Average block size: {acm / circuit.num_operations}")
# ```
# <div class="alert alert-block alert-info">
# <b>Note:</b> the use of the logging module. The printing passes will be run in a runtime worker process, which only successfully prints in jupyter through the logging module. Simple `print` will not work in jupyter notebooks but instead print the outputs in the terminal from which you launched jupyter.
# </div>

# %%
from bqskit.compiler.compiler import Compiler
from bqskit import MachineModel
from bqskit.passes import *
from bqskit import enable_logging
from bqskit.compiler.basepass import BasePass
from bqskit.ir.gates import CircuitGate, CNOTGate
import logging

enable_logging()

_logger = logging.getLogger("bqskit.notebook")

class PrintCNOTsPass(BasePass):
    async def run(self, circuit, data) -> None:
        _logger.info(f"BQSKit step, current CNOT count: {circuit.count(CNOTGate())}")
        
class PrintPartitionInfoPass(BasePass):
    async def run(self, circuit, data):
        acm = 0
        for op in circuit:            
            if not isinstance(op.gate, CircuitGate):
                _logger.info("Circuit not yet partitioned")
                return

            acm += op.gate._circuit.num_operations

        _logger.info(f"Number of partitions: {circuit.num_operations}")
        _logger.info(f"Average block size: {acm / circuit.num_operations}")
        
coupling_graph = [
    (0, 1), (0, 2), (0, 3), (1, 2), (1, 3), (2, 3)
]
model = MachineModel(4, coupling_graph=coupling_graph)

workflow = [
    PrintCNOTsPass(),
    SetModelPass(model),
    PrintPartitionInfoPass(),
    QuickPartitioner(),
    PrintPartitionInfoPass(),
    ForEachBlockPass([
        QSearchSynthesisPass(),
        ScanningGateRemovalPass()
    ], replace_filter='less-than-multi'),
    UnfoldPass(),
    PrintCNOTsPass()
]

with Compiler() as compiler:
    opt_circuit = compiler.compile(qiskit_to_bqskit(c_bk), workflow)
    
print("Gate Counts:", opt_circuit.gate_counts)
print("Connectivity:", opt_circuit.coupling_graph)
# Out:
# 10:38:31.854 - INFO     | bqskit.notebook: BQSKit step, current CNOT count: 90 [wid=84]
# 10:38:31.854 - INFO     | bqskit.notebook: Circuit not yet partitioned [wid=84]
# 10:38:31.875 - INFO     | bqskit.notebook: Number of partitions: 19 [wid=84]
# 10:38:31.875 - INFO     | bqskit.notebook: Average block size: 8.947368421052632 [wid=84]
# 10:38:42.483 - INFO     | bqskit.notebook: BQSKit step, current CNOT count: 68 [wid=84]
# Gate Counts: {CNOTGate: 68, RXGate: 15, RYGate: 46, RZGate: 17, U3Gate: 44}
# Connectivity: CouplingGraph({(0, 1), (1, 2), (0, 3), (2, 3), (0, 2), (1, 3)})

# %% [markdown]
# Seeded Synthesis for Improving Variational Workflows
# ----------------------------------------------------
#
# This section discusses how we can leverage knowledge about our specific problem, a variational Hubbard model simulation, to build a compilation workflow that fits its needs much better than BQSKit off-the-shelf.
# In a variational setting, we run many circuits sequentially, modifying them slightly between each iteration. The time cost between each iteration is significant in an experimental environment as QPU access time is not cheap for two main reasons.
# First, QPU time may cost actual currency and be very expensive, so we want to minimize the time idling waiting to compile a new circuit. Second, while idling the QPU may be drifting causing a type of noise that may be hard to handle in the algorithm.
# Therefore, a long-running compilation workflow may not be advantageous in a variational setting.
#
# This being said, there are two positive observations that we can make from this environment that we can use to guide the creation of a custom workflow:
#
# 1. We have practically unlimited time before accessing the QPU to perform analysis and compilation on the first circuit in sequence.
# 2. The circuits are not likely to change much between each iteration.
#
# The first observation allows us to perform deep compilation and analysis routines on the circuit before starting the algorithm.
# In contrast, the second point enables us to "seed" a compilation workflow from the results of a previous iteration.
#
# Over the rest of this section, we will first learn how to do compilation seed analysis, then combine that with first-compilation detection to build a variational compilation workflow that greatly improves compile time without hurting compile quality.
#
# But before we start, let's get a baseline:

# %%
from hubbard import EnergyObjective
from bqskit.ir.gates import CNOTGate
from bqskit.passes.partitioning import QuickPartitioner
from bqskit.passes.synthesis.qsearch import QSearchSynthesisPass
from bqskit.passes.processing import ScanningGateRemovalPass 
from bqskit.passes.control.foreach import ForEachBlockPass
from bqskit.compiler import Compiler
from bqskit.compiler.compile import get_instantiate_options

# To record how well we are doing
compiled_circuit_cnot_counts = []
instantiate_options = get_instantiate_options(optimization_level=1)

workflow = [
    QuickPartitioner(3), 
    ForEachBlockPass(
        QSearchSynthesisPass(instantiate_options=instantiate_options),
        ScanningGateRemovalPass(instantiate_options=instantiate_options)
    ),
    UnfoldPass(),
]

# Start a compiler
compiler = Compiler()

class BaselineObjective(EnergyObjective):
    def optimize_evolution(self, bqskit_circuit):
        compiled_circuit = compiler.compile(bqskit_circuit, workflow)
        compiled_circuit_cnot_counts.append(compiled_circuit.count(CNOTGate()))
        return compiled_circuit
    
bk_objective = BaselineObjective(hm_bk, **hm_filling)
start = timer()
min_energy = scipy.optimize.minimize(bk_objective, [0.1]*bk_objective.npar(), method='BFGS')
print("converged in %.0f seconds" % (timer() - start))
print("minimum energy: %.5f (exact: %.5f)" % (min_energy.fun, hubbard.exact(hm_bk, **hm_filling)))
print("Average CNOT gate count: %.2f" % np.mean(compiled_circuit_cnot_counts))

# Close the compiler
compiler.close()
# Out:
# converged in 112 seconds
# minimum energy: -1.00000 (exact: -1.00000)
# Average CNOT gate count: 84.91

# %% [markdown]
# Now, the goal of this section is to improve upon that runtime while not harming the CNOT quality.
#
# We are going to do this using a form of seeded synthesis. For a detailed walkthrough of this concept, refer to the [QSeed project](https://github.com/mtweiden/qseed).
# The general idea is that compiling similar circuits will be discover similar structures of our block-level optimizations, and by recognizing these, we can skip the block compilations altogether.
#
# Below are some helper functions that plot histograms of found structures and draw specified circuits.
#
# Structures from runs of synthesis are stored in the `AnalysisObjective.structures` list. These structures can be drawn using the `draw_structure` function defined below. `plot_structure_histograms` should take as input a list of structure circuits. It will show you which structures are most common in an optimized circuit. The structure associated with a label in the plotted histogram can be retrieved using `label_to_structure`.

# %%
from bqskit import Circuit
from bqskit.ir.gates import CNOTGate, U3Gate
import matplotlib.pyplot as plt
from bqskit.ir.lang.qasm2.qasm2 import OPENQASM2Language
from qiskit import QuantumCircuit


def plot_structure_histograms(structures_list):
    unique_structures = sorted(list(set(structures_list.copy())), key=len)
    counts = [structures_list.count(s) for s in unique_structures]
    labels = [l for (l, _) in enumerate(unique_structures)]
    plt.figure(figsize=(12, 4))
    plt.bar(labels, counts)
    plt.ylabel('Structure Frequency')
    plt.xlabel('Structure Labels')
    plt.xticks(labels)
    plt.show()


def draw_structure(structure):
    circuit = structure_to_circuit(structure, 3)
    lang = OPENQASM2Language()
    qasm = lang.encode(circuit)
    qk_circ = QuantumCircuit.from_qasm_str(qasm)
    print(qk_circ)


def label_to_structure(structures_list, label):
    unique_structures = sorted(list(set(structures_list.copy())), key=len)
    return unique_structures[label]


def structure_to_circuit(structure, num_qudits = 3):
    circuit = Circuit(num_qudits)
    for q in range(num_qudits):
        circuit.append_gate(U3Gate(), [q])
    for (q1, q2) in structure:
        circuit.append_gate(CNOTGate(), [q1, q2])
        circuit.append_gate(U3Gate(), [q1])
        circuit.append_gate(U3Gate(), [q2])
    return circuit


def count_cnots(partitioned_circuit: Circuit):
    circuit_copy = partitioned_circuit.copy()
    circuit_copy.unfold_all()
    return circuit_copy.gate_counts[CNOTGate()]


def get_structures(partitioned_circuit):
    circuit_copy = partitioned_circuit.copy()
    structures = []
    for block in circuit_copy:
        subcirc = Circuit.from_operation(block)
        subcirc.unfold_all()
        structures.append(tuple([
            tuple(op.location) for op in subcirc 
            if op.num_qudits == 2
        ]))
    return structures

# %% [markdown]
# Let's analyze a few of the iterations during the objective function analysis for good seeds:

# %%
# Since we are "off-the-QPU" during analysis, we can take our time and
# perform high-quality compilation. We will use a workflow that does
# QSearch synthesis with high-quality settings followed by gate deletion.
instantiate_options = get_instantiate_options(optimization_level=3)
workflow = [
    QuickPartitioner(3), 
    ForEachBlockPass(
        QSearchSynthesisPass(instantiate_options=instantiate_options),
        ScanningGateRemovalPass(instantiate_options=instantiate_options)
    ),
]

# To save time during analysis, we only want to do compilation and
# analysis once in a while during the algorithm. As you decrease this,
# you will get better seeds, but it will take longer.
analysis_period = 4

class AnalysisObjective(EnergyObjective):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.structures = []
        self.block_counter = 0

    def optimize_evolution(self, bqskit_circuit):
        if self.block_counter < analysis_period:
            self.block_counter += 1
            return bqskit_circuit
        
        self.block_counter = 0
        with Compiler() as compiler:
            opt_circuit = compiler.compile(bqskit_circuit, workflow)
            self.structures.append(get_structures(opt_circuit))
            opt_circuit.unfold_all()
        return opt_circuit

# We are only running this to get the structures, so we aren't printing anything here
bottomup_objective = AnalysisObjective(hm_bk, **hm_filling)
min_energy = scipy.optimize.minimize(bottomup_objective, [0.1]*bottomup_objective.npar(), method='BFGS')

# %% [markdown]
# Now try profiling the circuits using `plot_structure_histogram`.

# %%
structures = []
for structure_batch in bottomup_objective.structures:
    structures.extend(structure_batch)
plot_structure_histograms(structures)

# %% [markdown]
# **Exercise:** Visualize seeds of interest by putting their labels in the `seed_labels` list below.

# %%
seed_labels = [0, 5, 11, 17, 32]  # Put seeds of interest here!
for label in seed_labels:
    print(f'structure: {label}')
    draw_structure(label_to_structure(structures, label))
# Out:
# structure: 0
#      ┌───────────┐                       ┌───────────┐
# q_0: ┤ U3(0,0,0) ├────────────────────■──┤ U3(0,0,0) ├
#      ├───────────┤     ┌───────────┐┌─┴─┐├───────────┤
# q_1: ┤ U3(0,0,0) ├──■──┤ U3(0,0,0) ├┤ X ├┤ U3(0,0,0) ├
#      ├───────────┤┌─┴─┐├───────────┤└───┘└───────────┘
# q_2: ┤ U3(0,0,0) ├┤ X ├┤ U3(0,0,0) ├──────────────────
#      └───────────┘└───┘└───────────┘
# structure: 5
#      ┌───────────┐     ┌───────────┐                       ┌───────────┐
# q_0: ┤ U3(0,0,0) ├──■──┤ U3(0,0,0) ├────────────────────■──┤ U3(0,0,0) ├
#      ├───────────┤┌─┴─┐├───────────┤     ┌───────────┐┌─┴─┐├───────────┤
# q_1: ┤ U3(0,0,0) ├┤ X ├┤ U3(0,0,0) ├──■──┤ U3(0,0,0) ├┤ X ├┤ U3(0,0,0) ├
#      ├───────────┤└───┘└───────────┘┌─┴─┐├───────────┤└───┘└───────────┘
# q_2: ┤ U3(0,0,0) ├──────────────────┤ X ├┤ U3(0,0,0) ├──────────────────
#      └───────────┘                  └───┘└───────────┘
# structure: 11
#      ┌───────────┐     ┌───────────┐     ┌───────────┐                       »
# q_0: ┤ U3(0,0,0) ├──■──┤ U3(0,0,0) ├──■──┤ U3(0,0,0) ├───────────────────────»
#      ├───────────┤┌─┴─┐├───────────┤┌─┴─┐├───────────┤     ┌───────────┐     »
# q_1: ┤ U3(0,0,0) ├┤ X ├┤ U3(0,0,0) ├┤ X ├┤ U3(0,0,0) ├──■──┤ U3(0,0,0) ├──■──»
#      ├───────────┤└───┘└───────────┘└───┘└───────────┘┌─┴─┐├───────────┤┌─┴─┐»
# q_2: ┤ U3(0,0,0) ├────────────────────────────────────┤ X ├┤ U3(0,0,0) ├┤ X ├»
#      └───────────┘                                    └───┘└───────────┘└───┘»
# «                       ┌───────────┐
# «q_0: ───────────────■──┤ U3(0,0,0) ├
# «     ┌───────────┐┌─┴─┐├───────────┤
# «q_1: ┤ U3(0,0,0) ├┤ X ├┤ U3(0,0,0) ├
# «     ├───────────┤└───┘└───────────┘
# «q_2: ┤ U3(0,0,0) ├──────────────────
# «     └───────────┘
# structure: 17
#      ┌───────────┐                       ┌───────────┐     ┌───────────┐     »
# q_0: ┤ U3(0,0,0) ├────────────────────■──┤ U3(0,0,0) ├──■──┤ U3(0,0,0) ├─────»
#      ├───────────┤     ┌───────────┐┌─┴─┐├───────────┤┌─┴─┐├───────────┤     »
# q_1: ┤ U3(0,0,0) ├──■──┤ U3(0,0,0) ├┤ X ├┤ U3(0,0,0) ├┤ X ├┤ U3(0,0,0) ├──■──»
#      ├───────────┤┌─┴─┐├───────────┤└───┘└───────────┘└───┘└───────────┘┌─┴─┐»
# q_2: ┤ U3(0,0,0) ├┤ X ├┤ U3(0,0,0) ├────────────────────────────────────┤ X ├»
#      └───────────┘└───┘└───────────┘                                    └───┘»
# «
# «q_0: ───────────────────────────────
# «     ┌───────────┐     ┌───────────┐
# «q_1: ┤ U3(0,0,0) ├──■──┤ U3(0,0,0) ├
# «     ├───────────┤┌─┴─┐├───────────┤
# «q_2: ┤ U3(0,0,0) ├┤ X ├┤ U3(0,0,0) ├
# «     └───────────┘└───┘└───────────┘
# structure: 32
#      ┌───────────┐     ┌───────────┐     ┌───────────┐                       »
# q_0: ┤ U3(0,0,0) ├──■──┤ U3(0,0,0) ├──■──┤ U3(0,0,0) ├───────────────────────»
#      ├───────────┤┌─┴─┐├───────────┤┌─┴─┐├───────────┤     ┌───────────┐     »
# q_1: ┤ U3(0,0,0) ├┤ X ├┤ U3(0,0,0) ├┤ X ├┤ U3(0,0,0) ├──■──┤ U3(0,0,0) ├──■──»
#      ├───────────┤└───┘└───────────┘└───┘└───────────┘┌─┴─┐├───────────┤┌─┴─┐»
# q_2: ┤ U3(0,0,0) ├────────────────────────────────────┤ X ├┤ U3(0,0,0) ├┤ X ├»
#      └───────────┘                                    └───┘└───────────┘└───┘»
# «                                         ┌───────────┐
# «q_0: ─────────────────────────────────■──┤ U3(0,0,0) ├
# «     ┌───────────┐     ┌───────────┐┌─┴─┐├───────────┤
# «q_1: ┤ U3(0,0,0) ├──■──┤ U3(0,0,0) ├┤ X ├┤ U3(0,0,0) ├
# «     ├───────────┤┌─┴─┐├───────────┤└───┘└───────────┘
# «q_2: ┤ U3(0,0,0) ├┤ X ├┤ U3(0,0,0) ├──────────────────
# «     └───────────┘└───┘└───────────┘

# %% [markdown]
# Let's put this together now that we have done our analysis. Ideally, we have selected our seeds to start synthesis with, but this might require some experimenting.
#
# **Exercise:** After profiling, select one or more seeds by entering the associated integer label into the `seed_labels` list below.
# Note that some less common seeds may still be worth investigating if they are similar to more frequent ones.

# %%
seed_labels = [0, 5, 11, 17, 32]

assert len(seed_labels) > 0, "Make sure to put some seeds in the list above!"

# Build the seed structures
seeds = [structure_to_circuit(label_to_structure(structures, s)) for s in seed_labels]

# Build the workflow
layer_gen = SeedLayerGenerator(seeds)
instantiate_options = get_instantiate_options(optimization_level=3)
workflow = [
    QuickPartitioner(3), 
    ForEachBlockPass(
        QSearchSynthesisPass(
            layer_generator=layer_gen,
            instantiate_options=instantiate_options,
        ),
        ScanningGateRemovalPass(instantiate_options=instantiate_options)
    ),
    UnfoldPass()
]

# To record how well we are doing
compiled_circuit_cnot_counts = []

# Start a compiler
compiler = Compiler()

class SeededObjective(EnergyObjective):
    def optimize_evolution(self, bqskit_circuit):
        compiled_circuit = compiler.compile(bqskit_circuit, workflow)
        compiled_circuit_cnot_counts.append(compiled_circuit.count(CNOTGate()))
        return compiled_circuit

bk_objective = SeededObjective(hm_bk, **hm_filling)
start = timer()
min_energy = scipy.optimize.minimize(bk_objective, [0.1]*bk_objective.npar(), method='BFGS')
print("converged in %.0f seconds" % (timer() - start))
print("minimum energy: %.5f (exact: %.5f)" % (min_energy.fun, hubbard.exact(hm_bk, **hm_filling)))
print("Average CNOT gate count: %.2f" % np.mean(compiled_circuit_cnot_counts))

# Close the compiler
compiler.close()
# Out:
# converged in 550 seconds
# minimum energy: -0.99982 (exact: -1.00000)
# Average CNOT gate count: 80.59

# %% [markdown]
# How much speed up did you observe by using seeds? How much was the final CNOT count impacted compared to the baseline workflow? How many seeds do you use to get these results?

# %% [markdown]
# More information about a machine learning approach to seed recommendation can be found in the [QSeed paper](https://arxiv.org/abs/2306.05622) [7]. Circuit seeding in bqskit is done with the use of the [SeedLayerGenerator](https://bqskit.readthedocs.io/en/latest/source/autogen/bqskit.passes.SeedLayerGenerator.html).

# %% [markdown]
# ## References
# -------------
#
# [1] J. Hubbard, Proc. Roy. Soc. (Lond.) 276 (1963) 238
# <br>[2] https://github.com/scikit-quant/scikit-quant/tree/master/tutorials
# <br>[3] https://arxiv.org/abs/cond-mat/0012334, Ortiz et al., "Quantum Algorithms for Fermionic Simulations"
# <br>[4] P. Jordan and E. Wigner, "Über das Paulische Äquivalenzverbot", Z. Phys. 47, 631 (1928)
# <br>[5] https://arxiv.org/abs/quant-ph/0003137 S. Bravyi, A. Kitaev, "Fermionic quantum computation"
# <br>[6] https://arxiv.org/abs/1812.02233, A. Tranter, et al., "A comparison of the Bravyi-Kitaev and Jordan-Wigner transformations for the quantum simulation of quantum chemistry"
# <br>[7] https://arxiv.org/abs/2306.05622, M. Weiden, et al., "Improving Quantum Circuit Synthesis with Machine Learning"
